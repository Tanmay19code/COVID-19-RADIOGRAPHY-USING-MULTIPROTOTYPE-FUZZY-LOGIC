# %% [markdown]
# ## COVID-19 RADIOGRAPHY BASED CLASSIFICATION USING MULTIPROTOTYPE FUZZY LOGIC
# ------
# #### Batch 1 Grp 2 EDI :
# - 12011104 - Tanmay Mutalik
# - 12011328 - Vishal Govindani
# - 12011078 - Kuhu Mukhopadhyay
# - 12011385 - Amey Chopde
#
# ------
#
# ## About the Dataset:
# #### COVID-19 CHEST X-RAY DATABASE:
#
#
#         - A team of researchers from Qatar University, Doha, Qatar, and the University of Dhaka, Bangladesh along with their collaborators from Pakistan and Malaysia in collaboration with medical doctors have created a database of chest X-ray images for COVID-19 positive cases along with Normal and Viral Pneumonia images. This COVID-19, normal and other lung infection dataset is released in stages. In the first release we have released 219 COVID-19, 1341 normal and 1345 viral pneumonia chest X-ray (CXR) images. In the first update, we have increased the COVID-19 class to 1200 CXR images. In the 2nd update, we have increased the database to 3616 COVID-19 positive cases along with 10,192 Normal, 6012 Lung Opacity (Non-COVID lung infection) and 1345 Viral Pneumonia images and corresponding lung masks. We will continue to update this database as soon as we have new x-ray images for COVID-19 pneumonia patients.
#
# ##### Formats
#         - All the images are in Portable Network Graphics (PNG) file format and resolution are 299*299 pixels.
#
# ##### Objective
#        -  Researchers can use this database to produce useful and impactful scholarly work on COVID-19, which can help in tackling this pandemic.
#
# ##### COVID-19 data:
# >
# >COVID data are collected from different publicly accessible dataset, online sources and published papers.
# >- 2473 CXR images are collected from padchest dataset[1].
# >- 183 CXR images from a Germany medical school[2].
# >- 559 CXR image from SIRM, Github, Kaggle & Tweeter[3,4,5,6]
# >- 400 CXR images from another Github source[7].
#
#
# ##### Normal images:
# >10192 Normal data are collected from from three different dataset.
# >- 8851 RSNA [8]
# >- 1341 Kaggle [9]
#
#
# ##### Lung opacity images:
# >6012 Lung opacity CXR images are collected from Radiological Society of North America (RSNA) CXR dataset  [8]
#
# ##### Viral Pneumonia images:bo
# >1345 Viral Pneumonia data are collected from  the Chest X-Ray Images (pneumonia) database [9]
#
# ##### Dataset Link:
#
#
# [COVID-19 Chest X-Ray Database](https://www.kaggle.com/datasets/tawsifurrahman/covid19-radiography-database)
#
#
# ## Reference:
# [1]https://bimcv.cipf.es/bimcv-projects/bimcv-covid19/#1590858128006-9e640421-6711
#
# [2]https://github.com/ml-workgroup/covid-19-image-repository/tree/master/png
#
# [3]https://sirm.org/category/senza-categoria/covid-19/
#
# [4]https://eurorad.org
#
# [5]https://github.com/ieee8023/covid-chestxray-dataset
#
# [6]https://figshare.com/articles/COVID-19_Chest_X-Ray_Image_Repository/12580328
#
# [7]https://github.com/armiro/COVID-CXNet
#
# [8]https://www.kaggle.com/c/rsna-pneumonia-detection-challenge/data
#
# [9] https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia

# %% [markdown]
# # Code

# %%
# import the necessary packages
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as mpatches
import pandas as pd
import seaborn as sns
import ast
import pywt

# %% [markdown]
# ` Defining Functions for basic image processing `

# %%
# functions for image processing
#! add contrast to the image 
def contrast(img, alpha, beta):
    new_img = np.zeros(img.shape, img.dtype)
    for y in range(img.shape[0]):
        for x in range(img.shape[1]):
            for c in range(img.shape[2]):
                new_img[y,x,c] = np.clip(alpha*img[y,x,c] + beta, 0, 255)
    return new_img

#! add brightness to the image
def brightness(img, alpha, beta):
    new_img = np.zeros(img.shape, img.dtype)
    for y in range(img.shape[0]):
        for x in range(img.shape[1]):
            for c in range(img.shape[2]):
                new_img[y,x,c] = np.clip(alpha*img[y,x,c] + beta, 0, 255)
    return new_img

#! add gamma to the image
def gamma(img, gamma):
    gamma_table = [np.power(x/255.0, gamma)*255.0 for x in range(256)]
    gamma_table = np.round(np.array(gamma_table)).astype(np.uint8)
    return cv2.LUT(img, gamma_table)

#! add blur to the image
def blur(img, ksize):
    return cv2.blur(img, (ksize, ksize))

#! add sharpen to the image
def sharpen(img, ksize):
    kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    return cv2.filter2D(img, -1, kernel)

#! add emboss to the image
def emboss(img, ksize):
    kernel = np.array([[-2,-1,0], [-1,1,1], [0,1,2]])
    return cv2.filter2D(img, -1, kernel)

#! add edge detection to the image
def edge_detection(img, ksize):
    kernel = np.array([[-1,-1,-1], [-1,8,-1], [-1,-1,-1]])
    return cv2.filter2D(img, -1, kernel)

# %% [markdown]
# ` Defining functions for file handling `

# %%
def formatString(string):
    string = string.replace("array([", "[")
    string = string.replace("]),array([", "],[")
    string = string.replace("])", "]")
    return string


def convertToArray(string):
    listArr = ast.literal_eval(string)
    return listArr


def tupleToList(listArr):
    array = []
    for i in range(len(listArr)):
        array.append(listArr[i])
    return array

def loadFile(path):
    with open(path, 'r') as f:
        vector = f.read()
        vector = formatString(vector)
        vector = convertToArray(vector)
        vector = tupleToList(vector)
        f.close()
    return vector

# %%
#! function to return a vector of frequency of all intensities from 0 to 255

def get_img_vector(img):
    img_vector = np.zeros(256)
    for i in range(0, img.shape[0]):
        for j in range(0, img.shape[1]):
            img_vector[img[i][j]] += 1
    return img_vector


#! function to calculate euclidean distance between two vectors
def euclidean_distance(vector1, vector2):
    distance = 0.0
    for i in range(len(vector1)):
        distance += (vector1[i] - vector2[i])**2
    return np.sqrt(distance)


#! function to calculate manhattan distance between two vectors
def manhattan_distance(vector1, vector2):
    return np.sum(np.abs(vector1 - vector2))

# %% [markdown]
# ` Defining functions for prototypes`

# %%
def getPrototype(test_vector, prototypes):
    min_distance = euclidean_distance(test_vector, prototypes[0])
    index = 0
    for i in range(1, len(prototypes)):
        distance = euclidean_distance(test_vector, prototypes[i])
        if distance < min_distance:
            min_distance = distance
            index = i
    return index, min_distance


def assignClass(covid_membership, normal_membership, pneumonia_membership):
    if covid_membership>normal_membership and covid_membership> pneumonia_membership:
        return "covid"

    elif normal_membership>covid_membership and pneumonia_membership:
        return "normal"

    elif pneumonia_membership>normal_membership and covid_membership:
        return "pneumonia"

    elif normal_membership == covid_membership == pneumonia_membership:
        return "\nCovid, Normal, Pneumonia have same membership.Cannot assign a single class"
    
    elif normal_membership == covid_membership:
        return "\nNormal and Covid have same membership.Cannot assign a single class "
    
    elif normal_membership == pneumonia_membership:
        return "\nNormal and Pneumonia have same membership.Cannot assign a single class"
    elif covid_membership == pneumonia_membership:
        return "\nPneumonia and Covid have same membership.Cannot assign a single class"
    else:
        return "\n Some error occurred"


def accuracy(lengthTestVectors, lengthCorrectlyClassified):
    return (lengthCorrectlyClassified/lengthTestVectors)*100


def getDegreeOfMembership(className, covid_class_parameter, normal_class_parameter, pneumonia_class_parameter):
    degree = 0
    sum = covid_class_parameter + normal_class_parameter + pneumonia_class_parameter
    if className == "covid":
        element = covid_class_parameter
    elif className == "normal":
        element = normal_class_parameter
    elif className == "pneumonia":
        element = pneumonia_class_parameter

    degree = (sum - element) / sum
    return degree

# %% [markdown]
# ### Defining a process to check the validity of input image

# %%
# read sharpen images from the folder sharpen_images of lung_opacity
lung_opacity_sharpen_length =len(os.listdir('./COVID-19_Radiography_Dataset/Lung_Opacity/sharpen_images/'))
lung_opacity_sharpen = []

for i in range(1, lung_opacity_sharpen_length):
    img = cv2.imread('./COVID-19_Radiography_Dataset/Lung_Opacity/sharpen_images/Lung_Opacity-'+str(i)+'.png')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    lung_opacity_sharpen.append(img)

# display the 10 sharpen images
plt.figure(figsize=(10,10))
for i in range(0, 10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(lung_opacity_sharpen[i], cmap=plt.cm.binary)
    plt.xlabel('Lung_Opacity-'+str(i))
plt.show()

# get the average image
lung_opacity_average = np.mean(lung_opacity_sharpen, axis=0)

# display the average image
plt.figure(figsize=(10,10))
plt.subplot(5,5,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(lung_opacity_average, cmap=plt.cm.binary)
plt.xlabel('Average')
plt.show()

# %%
def is_lung_image(img):
    std = np.std(img)
    std_average = np.std(lung_opacity_average)
    # check if the input image is similar to the average image
    if std > std_average:
        return True
    else:
        return False

# %% [markdown]
# ## Load the Images
#
# ` Normal Lungs Images `
#
# ` Pneumonia Lungs Images `
#
# ` COVID Lungs Images `

# %%
covid_images_length = len(os.listdir('./COVID-19_Radiography_Dataset/COVID/sharpen_images/'))
normal_images_length = len(os.listdir('./COVID-19_Radiography_Dataset/Normal/sharpen_images/'))
viral_pneumonia_images_length = len(os.listdir('./COVID-19_Radiography_Dataset/Viral Pneumonia/sharpen_images/'))

#! read all images of normal
normal_images = []
for i in range(1, normal_images_length+1):
    normal_images.append(cv2.imread(
        './COVID-19_Radiography_Dataset/Normal/sharpen_images/Normal-'+str(i)+'.png'))

#! read all images of viral pneumonia
viral_pneumonia_images = []
for i in range(1, viral_pneumonia_images_length+1):
    viral_pneumonia_images.append(cv2.imread(
        './COVID-19_Radiography_Dataset/Viral Pneumonia/sharpen_images/Viral Pneumonia-'+str(i)+'.png'))

#! read all images of covid
covid_images = []
for i in range(1, covid_images_length+1):
    covid_images.append(cv2.imread(
        './COVID-19_Radiography_Dataset/COVID/sharpen_images/COVID-'+str(i)+'.png'))

# %%
#! Display 5 images from each class with labels with numbers
fig, axs = plt.subplots(3, 5, figsize=(15, 15))
for i in range(5):
    axs[0, i].imshow(normal_images[i])
    axs[0, i].set_title('Normal-'+str(i+1))
    axs[1, i].imshow(viral_pneumonia_images[i])
    axs[1, i].set_title('Viral Pneumonia'+str(i+1))
    axs[2, i].imshow(covid_images[i])
    axs[2, i].set_title('COVID'+str(i+1))
plt.show()

# %% [markdown]
# ## Load the Vectors
#
# ` Normal Lungs Vector `
#
# ` Pneumonia Lungs Vector `
#
# ` COVID Lungs Vector `

# %%
normal_images_vector = []
covid_images_vector = []
pneumonia_images_vector = []

#! get vector of all images of normal
normal_images_vector = loadFile('./COVID-19_Radiography_Dataset/Normal/normal_images_vector.txt')
#! get vector of all images of covid
covid_images_vector = loadFile('./COVID-19_Radiography_Dataset/COVID/covid_images_vector.txt')
#! get vector of all images of viral pneumonia
pneumonia_images_vector = loadFile('./COVID-19_Radiography_Dataset/Viral Pneumonia/viral_pneumonia_images_vector.txt')

#! print vector of all classes
print("No. of Normal Images Vector: ", len(normal_images_vector))
print("No. of COVID Images Vector: ", len(covid_images_vector))
print("No. of Pneumonia Images Vector: ", len(pneumonia_images_vector))
# Out:
# No. of Normal Images Vector:  10192
# No. of COVID Images Vector:  3616
# No. of Pneumonia Images Vector:  1345

# %%
#! display the data distribution of each class
fig, axs = plt.subplots(3, 1, figsize=(15, 15))
axs[0].hist(normal_images_vector[11])    
axs[0].set_title('Normal Images Vector')
axs[1].hist(covid_images_vector[11])
axs[1].set_title('COVID Images Vector')
axs[2].hist(pneumonia_images_vector[11])
axs[2].set_title('Pneumonia Images Vector')
plt.show()

# %%
#! histogram of a vector in each class

# add some space between subplots
fig.subplots_adjust(hspace=5)
fig, axs = plt.subplots(3, 1, figsize=(15, 15))
axs[0].plot(normal_images_vector[11])
axs[0].set_title('Normal Images Vector')
axs[1].plot(covid_images_vector[11])
axs[1].set_title('COVID Images Vector')
axs[2].plot(pneumonia_images_vector[11])
axs[2].set_title('Pneumonia Images Vector')
plt.show()

# %%
#! display scatter plot a vector in each class
fig, axs = plt.subplots(3, 1, figsize=(15, 15))
axs[0].scatter(range(256), normal_images_vector[11])
axs[0].set_title('Normal Images Vector')
axs[1].scatter(range(256), covid_images_vector[11])
axs[1].set_title('COVID Images Vector')
axs[2].scatter(range(256), pneumonia_images_vector[11])
axs[2].set_title('Pneumonia Images Vector')
plt.show()

# %%
# disply the scatter plot of all classes in same graph
fig, axs = plt.subplots(1, 1, figsize=(15, 15))
axs.scatter(range(256), normal_images_vector[11], alpha=0.5, label='Normal')
axs.scatter(range(256), covid_images_vector[11], alpha=0.5, label='COVID')
axs.scatter(range(256), pneumonia_images_vector[11], alpha=0.5, label='Pneumonia')
axs.legend(loc='upper right')
plt.show()

# %%
# display the vectors in 3D dimensional space
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(normal_images_vector[11], normal_images_vector[12], normal_images_vector[13], c='b', marker='o', label='Normal')
ax.scatter(covid_images_vector[11], covid_images_vector[12], covid_images_vector[13], c='r', marker='o', label='COVID')
ax.scatter(pneumonia_images_vector[11], pneumonia_images_vector[12], pneumonia_images_vector[13], c='g', marker='o', label='Pneumonia')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Make clusters for each classes
#
#     - cluster the vectors that are within the initial threshold distance 10000
#     - r = 10000

# %%
normal_clusters = []
pneumonia_clusters = []
covid_clusters  = []

r = 10000

# %% [markdown]
# ` Initial Covid Clustering `

# %%
#! covid clusters
cluster = []
check = []
for i in range(0, len(covid_images_vector)-1):
    cluster = []
    if covid_images_vector[i] not in check:
        cluster.append(covid_images_vector[i])
        check.append(covid_images_vector[i])
    else:
        continue
    for j in range(i+1, len(covid_images_vector)):

        if euclidean_distance(covid_images_vector[i], covid_images_vector[j]) <= r:
            if covid_images_vector[j] not in check:
                cluster.append(covid_images_vector[j])
                check.append(covid_images_vector[j])

    covid_clusters.append(cluster)

# %%
# print the clusters
sum=0
for i in range(0, len(covid_clusters)):
    print("Covid Cluster -", i+1, " : ", len(covid_clusters[i]))
    sum+=len(covid_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Covid Cluster - 1  :  3214
# Covid Cluster - 2  :  182
# Covid Cluster - 3  :  2
# Covid Cluster - 4  :  40
# Covid Cluster - 5  :  31
# Covid Cluster - 6  :  8
# Covid Cluster - 7  :  23
# Covid Cluster - 8  :  28
# Covid Cluster - 9  :  1
# Covid Cluster - 10  :  5
# Covid Cluster - 11  :  3
# Covid Cluster - 12  :  3
# Covid Cluster - 13  :  1
# Covid Cluster - 14  :  6
# Covid Cluster - 15  :  1
# Covid Cluster - 16  :  1
# Covid Cluster - 17  :  6
# Covid Cluster - 18  :  1
# Covid Cluster - 19  :  1
# Covid Cluster - 20  :  2
# Covid Cluster - 21  :  1
# Covid Cluster - 22  :  1
# Covid Cluster - 23  :  1
# Covid Cluster - 24  :  1
# Covid Cluster - 25  :  1
# Covid Cluster - 26  :  1
# Total number of vectors:  3565

# %%
# plot graph to show cluster index vs cluster size of covid clusters

for i in range(0, len(covid_clusters)):
    plt.scatter(i, len(covid_clusters[i]), color='red') 

plt.title('Covid Clusters')
plt.xlabel('Cluster Index')
plt.ylabel('Cluster Size')
plt.show()

# %% [markdown]
# ` Initial Normal Clustering `

# %%
#! normal clusters
cluster = []
check = []
for i in range(0, len(normal_images_vector)-1):
    cluster = []
    if normal_images_vector[i] not in check:
        cluster.append(normal_images_vector[i])
        check.append(normal_images_vector[i])
    else:
        continue
    for j in range(i+1, len(normal_images_vector)):

        if euclidean_distance(normal_images_vector[i], normal_images_vector[j]) <= r:
            if normal_images_vector[j] not in check:
                cluster.append(normal_images_vector[j])
                check.append(normal_images_vector[j])

    normal_clusters.append(cluster)

# %%
# print the clusters
sum=0
for i in range(0, len(normal_clusters)):
    print("Normal Cluster -", i+1, " : ", len(normal_clusters[i]))
    sum+=len(normal_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Normal Cluster - 1  :  92
# Normal Cluster - 2  :  9028
# Normal Cluster - 3  :  861
# Normal Cluster - 4  :  1
# Normal Cluster - 5  :  8
# Normal Cluster - 6  :  59
# Normal Cluster - 7  :  21
# Normal Cluster - 8  :  1
# Normal Cluster - 9  :  5
# Normal Cluster - 10  :  14
# Normal Cluster - 11  :  14
# Normal Cluster - 12  :  10
# Normal Cluster - 13  :  7
# Normal Cluster - 14  :  8
# Normal Cluster - 15  :  7
# Normal Cluster - 16  :  5
# Normal Cluster - 17  :  6
# Normal Cluster - 18  :  1
# Normal Cluster - 19  :  2
# Normal Cluster - 20  :  1
# Normal Cluster - 21  :  9
# Normal Cluster - 22  :  3
# Normal Cluster - 23  :  3
# Normal Cluster - 24  :  2
# Normal Cluster - 25  :  1
# Normal Cluster - 26  :  6
# Normal Cluster - 27  :  3
# Normal Cluster - 28  :  2
# Normal Cluster - 29  :  1
# Normal Cluster - 30  :  3
# Normal Cluster - 31  :  1
# Normal Cluster - 32  :  2
# Normal Cluster - 33  :  1
# Normal Cluster - 34  :  1
# Normal Cluster - 35  :  1
# Normal Cluster - 36  :  1
# Total number of vectors:  10191

# %%
#  plot graph to show cluster index vs cluster size of normal clusters

for i in range(0, len(normal_clusters)):
    plt.scatter(i, len(normal_clusters[i]), color='blue')

plt.title('Normal Clusters')
plt.xlabel('Cluster Index')
plt.ylabel('Cluster Size')
plt.show()

# %% [markdown]
# ` Initial Pneumonia Clustering `

# %%
#! pneumonia clusters
cluster = []
check = []
for i in range(0, len(pneumonia_images_vector)-1):
    cluster = []
    if pneumonia_images_vector[i] not in check:
        cluster.append(pneumonia_images_vector[i])
        check.append(pneumonia_images_vector[i])
    else:
        continue
    for j in range(i+1, len(pneumonia_images_vector)):

        if euclidean_distance(pneumonia_images_vector[i], pneumonia_images_vector[j]) <= r:
            if pneumonia_images_vector[j] not in check:
                cluster.append(pneumonia_images_vector[j])
                check.append(pneumonia_images_vector[j])

    pneumonia_clusters.append(cluster)

# %%
# print the clusters
sum=0
for i in range(0, len(pneumonia_clusters)):
    print("Pneumonia Cluster -", i+1, " : ", len(pneumonia_clusters[i]))
    sum+=len(pneumonia_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Pneumonia Cluster - 1  :  1283
# Pneumonia Cluster - 2  :  51
# Pneumonia Cluster - 3  :  2
# Pneumonia Cluster - 4  :  2
# Total number of vectors:  1338

# %%
#  plot graph to show cluster index vs cluster size of pneumonia clusters

for i in range(0, len(pneumonia_clusters)):
    plt.scatter(i, len(pneumonia_clusters[i]), color='green')

plt.title('Pneumonia Clusters')
plt.xlabel('Cluster Index')
plt.ylabel('Cluster Size')
plt.show()

# %% [markdown]
# ### Remove outliers from clusters
#
#     - the clusters having less than 10 vectors can be removed as they are outliers

# %% [markdown]
# ` Remove Outliers from Normal Clusters `

# %%
normal_outliers = []
cleaned_normal_clusters = []
for i in normal_clusters:
    if len(i) < 10:
        normal_outliers.extend(i)
    else:
        cleaned_normal_clusters.append(i)

# %%
# print the outliers
print("Outliers: ", len(normal_outliers))

# print the clusters
sum=0
for i in range(0, len(cleaned_normal_clusters)):
    print("Cluster ", i+1, " : ", len(cleaned_normal_clusters[i]))
    sum+=len(cleaned_normal_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Outliers:  92
# Cluster  1  :  92
# Cluster  2  :  9028
# Cluster  3  :  861
# Cluster  4  :  59
# Cluster  5  :  21
# Cluster  6  :  14
# Cluster  7  :  14
# Cluster  8  :  10
# Total number of vectors:  10099

# %% [markdown]
# ` Remove Outliers from Pneumonia Clusters `

# %%
pneumonia_outliers = []
cleaned_pneumonia_clusters = []
for i in pneumonia_clusters:
    if len(i) < 10:
        pneumonia_outliers.extend(i)
    else:
        cleaned_pneumonia_clusters.append(i)

# %%
# print the outliers
print("Outliers: ", len(pneumonia_outliers))

# print the clusters
sum=0
for i in range(0, len(cleaned_pneumonia_clusters)):
    print("Cluster ", i+1, " : ", len(cleaned_pneumonia_clusters[i]))
    sum+=len(cleaned_pneumonia_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Outliers:  4
# Cluster  1  :  1283
# Cluster  2  :  51
# Total number of vectors:  1334

# %% [markdown]
# ` Remove Outliers from Covid Clusters ` `

# %%
covid_outliers = []
cleaned_covid_clusters = []
for i in covid_clusters:
    if len(i) < 10:
        covid_outliers.extend(i)
    else:
        cleaned_covid_clusters.append(i)

# %%
# print the outliers
print("Outliers: ", len(covid_outliers))

# print the clusters
sum=0
for i in range(0, len(cleaned_covid_clusters)):
    print("Cluster ", i+1, " : ", len(cleaned_covid_clusters[i]))
    sum+=len(cleaned_covid_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Outliers:  47
# Cluster  1  :  3214
# Cluster  2  :  182
# Cluster  3  :  40
# Cluster  4  :  31
# Cluster  5  :  23
# Cluster  6  :  28
# Total number of vectors:  3518

# %% [markdown]
#     - We get the clusters after removing outliers
#     - convert the clusters back into 1-D array for re-clustering

# %%
# covert the cleaned_normal_clusters to one dimensional list
updated_normal_vectors = [item for sublist in cleaned_normal_clusters for item in sublist]

# print the updated_normal_vectors
print("Updated normal vectors: ", len(updated_normal_vectors))
# Out:
# Updated normal vectors:  10099

# %%
# convert the cleaned_pneumonia_clusters to one dimensional list
updated_pneumonia_vectors = [item for sublist in cleaned_pneumonia_clusters for item in sublist]

# print the updated_pneumonia_vectors
print("Updated pneumonia vectors: ", len(updated_pneumonia_vectors))
# Out:
# Updated pneumonia vectors:  1334

# %%
# convert the cleaned_covid_clusters to one dimensional list
updated_covid_vectors = [item for sublist in cleaned_covid_clusters for item in sublist]

# print the updated_covid_vectors
print("Updated covid vectors: ", len(updated_covid_vectors))
# Out:
# Updated covid vectors:  3518

# %% [markdown]
# ### Reclustering
#
#     - Recluster the vectors that are within the threshold distance r which can be vary according to number of vectors

# %% [markdown]
# ` Reclustering normal vectors `

# %%
r = 1200

updated_normal_clusters = []  # list of clusters

updated_cluster=[]
check = []
for i in range(0, len(updated_normal_vectors)-1):
    updated_cluster = []
    if updated_normal_vectors[i] not in check:
        updated_cluster.append(updated_normal_vectors[i])
        check.append(updated_normal_vectors[i])
    else:
        continue
    for j in range(i+1, len(updated_normal_vectors)):

        if euclidean_distance(updated_normal_vectors[i], updated_normal_vectors[j]) <= r:
            if updated_normal_vectors[j] not in check:
                updated_cluster.append(updated_normal_vectors[j])
                check.append(updated_normal_vectors[j])

    updated_normal_clusters.append(updated_cluster)

# %%
# print the clusters
sum=0
for i in range(0, len(updated_normal_clusters)):
    print("Cluster ", i+1, " : ", len(updated_normal_clusters[i]))
    sum+=len(updated_normal_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Cluster  1  :  1
# Cluster  2  :  1
# Cluster  3  :  4
# Cluster  4  :  1
# Cluster  5  :  1
# Cluster  6  :  4
# Cluster  7  :  3
# Cluster  8  :  1
# Cluster  9  :  1
# Cluster  10  :  2
# Cluster  11  :  4
# Cluster  12  :  1
# Cluster  13  :  1
# Cluster  14  :  1
# Cluster  15  :  5
# Cluster  16  :  2
# Cluster  17  :  1
# Cluster  18  :  1
# Cluster  19  :  1
# Cluster  20  :  1
# Cluster  21  :  1
# Cluster  22  :  1
# Cluster  23  :  1
# Cluster  24  :  1
# Cluster  25  :  1
# Cluster  26  :  1
# Cluster  27  :  1
# Cluster  28  :  1
# Cluster  29  :  2
# Cluster  30  :  1
# Cluster  31  :  1
# Cluster  32  :  1
# Cluster  33  :  1
# Cluster  34  :  1
# Cluster  35  :  1
# Cluster  36  :  1
# Cluster  37  :  1
# Cluster  38  :  1
# Cluster  39  :  2
# Cluster  40  :  1
# Cluster  41  :  1
# Cluster  42  :  1
# Cluster  43  :  1
# Cluster  44  :  1
# Cluster  45  :  1
# Cluster  46  :  1
# Cluster  47  :  1
# Cluster  48  :  1
# Cluster  49  :  1
# Cluster  50  :  1
# Cluster  51  :  1
# Cluster  52  :  1
# Cluster  53  :  1
# Cluster  54  :  1
# Cluster  55  :  1
# Cluster  56  :  1
# Cluster  57  :  1
# Cluster  58  :  1
# Cluster  59  :  1
# Cluster  60  :  1
# Cluster  61  :  1
# Cluster  62  :  1
# Cluster  63  :  1
# Cluster  64  :  1
# Cluster  65  :  1
# Cluster  66  :  1
# Cluster  67  :  1
# Cluster  68  :  2
# Cluster  69  :  1
# Cluster  70  :  1
# Cluster  71  :  1
# Cluster  72  :  1
# Cluster  73  :  1
# Cluster  74  :  1
# Cluster  75  :  1
# Cluster  76  :  1
# Cluster  77  :  1
# Cluster  78  :  1
# Cluster  79  :  1
# Cluster  80  :  2
# Cluster  81  :  37
# Cluster  82  :  9
# Cluster  83  :  11
# Cluster  84  :  47
# Cluster  85  :  1
# Cluster  86  :  53
# Cluster  87  :  1
# Cluster  88  :  18
# Cluster  89  :  17
# Cluster  90  :  3
# Cluster  91  :  75
# Cluster  92  :  1
# Cluster  93  :  8
# Cluster  94  :  3
# Cluster  95  :  3
# Cluster  96  :  1
# Cluster  97  :  1
# Cluster  98  :  7
# Cluster  99  :  1
# Cluster  100  :  3
# Cluster  101  :  1
# Cluster  102  :  1
# Cluster  103  :  1
# Cluster  104  :  5
# Cluster  105  :  2
# Cluster  106  :  1
# Cluster  107  :  1
# Cluster  108  :  1
# Cluster  109  :  1
# Cluster  110  :  2
# Cluster  111  :  1
# Cluster  112  :  13
# Cluster  113  :  13
# Cluster  114  :  15
# Cluster  115  :  1
# Cluster  116  :  8
# Cluster  117  :  5
# Cluster  118  :  39
# Cluster  119  :  1
# Cluster  120  :  3
# Cluster  121  :  1
# Cluster  122  :  8
# Cluster  123  :  32
# Cluster  124  :  2
# Cluster  125  :  2
# Cluster  126  :  7
# Cluster  127  :  1
# Cluster  128  :  1
# Cluster  129  :  17
# Cluster  130  :  1
# Cluster  131  :  11
# Cluster  132  :  1
# Cluster  133  :  8
# Cluster  134  :  2
# Cluster  135  :  2
# Cluster  136  :  7
# Cluster  137  :  2
# Cluster  138  :  25
# Cluster  139  :  80
# Cluster  140  :  39
# Cluster  141  :  16
# Cluster  142  :  7
# Cluster  143  :  1
# Cluster  144  :  24
# Cluster  145  :  38
# Cluster  146  :  35
# Cluster  147  :  6
# Cluster  148  :  3
# Cluster  149  :  19
# Cluster  150  :  2
# Cluster  151  :  18
# Cluster  152  :  57
# Cluster  153  :  55
# Cluster  154  :  31
# Cluster  155  :  35
# Cluster  156  :  22
# Cluster  157  :  6
# Cluster  158  :  1
# Cluster  159  :  1
# Cluster  160  :  5
# Cluster  161  :  1
# Cluster  162  :  2
# Cluster  163  :  1
# Cluster  164  :  4
# Cluster  165  :  4
# Cluster  166  :  4
# Cluster  167  :  20
# Cluster  168  :  1
# Cluster  169  :  4
# Cluster  170  :  1
# Cluster  171  :  3
# Cluster  172  :  1
# Cluster  173  :  5
# Cluster  174  :  22
# Cluster  175  :  15
# Cluster  176  :  2
# Cluster  177  :  2
# Cluster  178  :  2
# Cluster  179  :  6
# Cluster  180  :  4
# Cluster  181  :  11
# Cluster  182  :  3
# Cluster  183  :  9
# Cluster  184  :  5
# Cluster  185  :  3
# Cluster  186  :  1
# Cluster  187  :  8
# Cluster  188  :  1
# Cluster  189  :  1
# Cluster  190  :  1
# Cluster  191  :  2
# Cluster  192  :  4
# Cluster  193  :  3
# Cluster  194  :  7
# Cluster  195  :  1
# Cluster  196  :  3
# Cluster  197  :  1
# Cluster  198  :  1
# Cluster  199  :  1
# Cluster  200  :  4
# Cluster  201  :  1
# Cluster  202  :  1
# Cluster  203  :  3
# Cluster  204  :  2
# Cluster  205  :  1
# Cluster  206  :  12
# Cluster  207  :  1
# Cluster  208  :  3
# Cluster  209  :  2
# Cluster  210  :  3
# Cluster  211  :  8
# Cluster  212  :  10
# Cluster  213  :  1
# Cluster  214  :  9
# Cluster  215  :  10
# Cluster  216  :  5
# Cluster  217  :  3
# Cluster  218  :  16
# Cluster  219  :  2
# Cluster  220  :  1
# Cluster  221  :  2
# Cluster  222  :  2
# Cluster  223  :  4
# Cluster  224  :  1
# Cluster  225  :  4
# Cluster  226  :  2
# Cluster  227  :  2
# Cluster  228  :  1
# Cluster  229  :  5
# Cluster  230  :  1
# Cluster  231  :  2
# Cluster  232  :  4
# Cluster  233  :  1
# Cluster  234  :  1
# Cluster  235  :  2
# Cluster  236  :  6
# Cluster  237  :  1
# Cluster  238  :  1
# Cluster  239  :  1
# Cluster  240  :  3
# Cluster  241  :  1
# Cluster  242  :  3
# Cluster  243  :  1
# Cluster  244  :  1
# Cluster  245  :  1
# Cluster  246  :  1
# Cluster  247  :  2
# Cluster  248  :  1
# Cluster  249  :  2
# Cluster  250  :  1
# Cluster  251  :  1
# Cluster  252  :  5
# Cluster  253  :  5
# Cluster  254  :  1
# Cluster  255  :  1
# Cluster  256  :  1
# Cluster  257  :  5
# Cluster  258  :  1
# Cluster  259  :  2
# Cluster  260  :  1
# Cluster  261  :  1
# Cluster  262  :  1
# Cluster  263  :  3
# Cluster  264  :  1
# Cluster  265  :  1
# Cluster  266  :  4
# Cluster  267  :  1
# Cluster  268  :  1
# Cluster  269  :  2
# Cluster  270  :  1
# Cluster  271  :  1
# Cluster  272  :  1
# Cluster  273  :  10
# Cluster  274  :  1
# Cluster  275  :  5
# Cluster  276  :  1
# Cluster  277  :  1
# Cluster  278  :  4
# Cluster  279  :  1
# Cluster  280  :  1
# Cluster  281  :  1
# Cluster  282  :  3
# Cluster  283  :  1
# Cluster  284  :  3
# Cluster  285  :  1
# Cluster  286  :  1
# Cluster  287  :  1
# Cluster  288  :  1
# Cluster  289  :  1
# Cluster  290  :  1
# Cluster  291  :  2
# Cluster  292  :  2
# Cluster  293  :  5
# Cluster  294  :  1
# Cluster  295  :  2
# Cluster  296  :  1
# Cluster  297  :  1
# Cluster  298  :  3
# Cluster  299  :  1
# Cluster  300  :  1
# Cluster  301  :  2
# Cluster  302  :  1
# Cluster  303  :  3
# Cluster  304  :  1
# Cluster  305  :  2
# Cluster  306  :  1
# Cluster  307  :  1
# Cluster  308  :  2
# Cluster  309  :  1
# Cluster  310  :  1
# Cluster  311  :  1
# Cluster  312  :  1
# Cluster  313  :  2
# Cluster  314  :  1
# Cluster  315  :  1
# Cluster  316  :  1
# Cluster  317  :  1
# Cluster  318  :  2
# Cluster  319  :  1
# Cluster  320  :  1
# Cluster  321  :  2
# Cluster  322  :  1
# Cluster  323  :  1
# Cluster  324  :  1
# Cluster  325  :  1
# Cluster  326  :  1
# Cluster  327  :  1
# Cluster  328  :  1
# Cluster  329  :  1
# Cluster  330  :  4
# Cluster  331  :  2
# Cluster  332  :  5
# Cluster  333  :  1
# Cluster  334  :  1
# Cluster  335  :  1
# Cluster  336  :  1
# Cluster  337  :  1
# Cluster  338  :  1
# Cluster  339  :  1
# Cluster  340  :  1
# Cluster  341  :  1
# Cluster  342  :  1
# Cluster  343  :  1
# Cluster  344  :  7
# Cluster  345  :  33
# Cluster  346  :  1
# Cluster  347  :  3
# Cluster  348  :  45
# Cluster  349  :  1
# Cluster  350  :  26
# Cluster  351  :  35
# Cluster  352  :  1
# Cluster  353  :  8
# Cluster  354  :  1
# Cluster  355  :  3
# Cluster  356  :  1
# Cluster  357  :  2
# Cluster  358  :  2
# Cluster  359  :  1
# Cluster  360  :  63
# Cluster  361  :  14
# Cluster  362  :  8
# Cluster  363  :  3
# Cluster  364  :  1
# Cluster  365  :  3
# Cluster  366  :  1
# Cluster  367  :  2
# Cluster  368  :  11
# Cluster  369  :  1
# Cluster  370  :  8
# Cluster  371  :  3
# Cluster  372  :  3
# Cluster  373  :  7
# Cluster  374  :  49
# Cluster  375  :  17
# Cluster  376  :  32
# Cluster  377  :  1
# Cluster  378  :  1
# Cluster  379  :  3
# Cluster  380  :  1
# Cluster  381  :  2
# Cluster  382  :  1
# Cluster  383  :  1
# Cluster  384  :  2
# Cluster  385  :  4
# Cluster  386  :  10
# Cluster  387  :  11
# Cluster  388  :  1
# Cluster  389  :  9
# Cluster  390  :  2
# Cluster  391  :  1
# Cluster  392  :  12
# Cluster  393  :  1
# Cluster  394  :  5
# Cluster  395  :  18
# Cluster  396  :  14
# Cluster  397  :  63
# Cluster  398  :  12
# Cluster  399  :  2
# Cluster  400  :  10
# Cluster  401  :  2
# Cluster  402  :  1
# Cluster  403  :  1
# Cluster  404  :  1
# Cluster  405  :  2
# Cluster  406  :  1
# Cluster  407  :  1
# Cluster  408  :  1
# Cluster  409  :  17
# Cluster  410  :  1
# Cluster  411  :  1
# Cluster  412  :  7
# Cluster  413  :  10
# Cluster  414  :  1
# Cluster  415  :  2
# Cluster  416  :  1
# Cluster  417  :  10
# Cluster  418  :  4
# Cluster  419  :  49
# Cluster  420  :  4
# Cluster  421  :  2
# Cluster  422  :  23
# Cluster  423  :  1
# Cluster  424  :  17
# Cluster  425  :  39
# Cluster  426  :  4
# Cluster  427  :  1
# Cluster  428  :  17
# Cluster  429  :  10
# Cluster  430  :  16
# Cluster  431  :  10
# Cluster  432  :  2
# Cluster  433  :  7
# Cluster  434  :  6
# Cluster  435  :  1
# Cluster  436  :  4
# Cluster  437  :  2
# Cluster  438  :  4
# Cluster  439  :  1
# Cluster  440  :  2
# Cluster  441  :  1
# Cluster  442  :  1
# Cluster  443  :  3
# Cluster  444  :  1
# Cluster  445  :  4
# Cluster  446  :  1
# Cluster  447  :  1
# Cluster  448  :  13
# Cluster  449  :  2
# Cluster  450  :  10
# Cluster  451  :  2
# Cluster  452  :  5
# Cluster  453  :  1
# Cluster  454  :  4
# Cluster  455  :  2
# Cluster  456  :  11
# Cluster  457  :  3
# Cluster  458  :  7
# Cluster  459  :  1
# Cluster  460  :  1
# Cluster  461  :  1
# Cluster  462  :  1
# Cluster  463  :  3
# Cluster  464  :  10
# Cluster  465  :  1
# Cluster  466  :  3
# Cluster  467  :  5
# Cluster  468  :  6
# Cluster  469  :  1
# Cluster  470  :  2
# Cluster  471  :  1
# Cluster  472  :  1
# Cluster  473  :  1
# Cluster  474  :  13
# Cluster  475  :  1
# Cluster  476  :  1
# Cluster  477  :  1
# Cluster  478  :  14
# Cluster  479  :  1
# Cluster  480  :  3
# Cluster  481  :  27
# Cluster  482  :  1
# Cluster  483  :  1
# Cluster  484  :  3
# Cluster  485  :  6
# Cluster  486  :  2
# Cluster  487  :  10
# Cluster  488  :  1
# Cluster  489  :  2
# Cluster  490  :  1
# Cluster  491  :  2
# Cluster  492  :  5
# Cluster  493  :  1
# Cluster  494  :  5
# Cluster  495  :  2
# Cluster  496  :  2
# Cluster  497  :  3
# Cluster  498  :  3
# Cluster  499  :  10
# Cluster  500  :  2
# Cluster  501  :  12
# Cluster  502  :  2
# Cluster  503  :  3
# Cluster  504  :  12
# Cluster  505  :  10
# Cluster  506  :  1
# Cluster  507  :  2
# Cluster  508  :  3
# Cluster  509  :  1
# Cluster  510  :  16
# Cluster  511  :  3
# Cluster  512  :  1
# Cluster  513  :  1
# Cluster  514  :  3
# Cluster  515  :  2
# Cluster  516  :  1
# Cluster  517  :  1
# Cluster  518  :  1
# Cluster  519  :  1
# Cluster  520  :  5
# Cluster  521  :  1
# Cluster  522  :  2
# Cluster  523  :  9
# Cluster  524  :  1
# Cluster  525  :  24
# Cluster  526  :  6
# Cluster  527  :  1
# Cluster  528  :  3
# Cluster  529  :  13
# Cluster  530  :  1
# Cluster  531  :  3
# Cluster  532  :  1
# Cluster  533  :  1
# Cluster  534  :  2
# Cluster  535  :  22
# Cluster  536  :  2
# Cluster  537  :  1
# Cluster  538  :  2
# Cluster  539  :  1
# Cluster  540  :  1
# Cluster  541  :  1
# Cluster  542  :  2
# Cluster  543  :  3
# Cluster  544  :  7
# Cluster  545  :  1
# Cluster  546  :  1
# Cluster  547  :  9
# Cluster  548  :  5
# Cluster  549  :  1
# Cluster  550  :  1
# Cluster  551  :  1
# Cluster  552  :  16
# Cluster  553  :  2
# Cluster  554  :  1
# Cluster  555  :  1
# Cluster  556  :  26
# Cluster  557  :  1
# Cluster  558  :  8
# Cluster  559  :  1
# Cluster  560  :  9
# Cluster  561  :  2
# Cluster  562  :  1
# Cluster  563  :  3
# Cluster  564  :  16
# Cluster  565  :  13
# Cluster  566  :  1
# Cluster  567  :  2
# Cluster  568  :  1
# Cluster  569  :  6
# Cluster  570  :  3
# Cluster  571  :  2
# Cluster  572  :  22
# Cluster  573  :  3
# Cluster  574  :  4
# Cluster  575  :  4
# Cluster  576  :  1
# Cluster  577  :  2
# Cluster  578  :  1
# Cluster  579  :  1
# Cluster  580  :  4
# Cluster  581  :  5
# Cluster  582  :  1
# Cluster  583  :  4
# Cluster  584  :  16
# Cluster  585  :  2
# Cluster  586  :  1
# Cluster  587  :  2
# Cluster  588  :  7
# Cluster  589  :  2
# Cluster  590  :  1
# Cluster  591  :  2
# Cluster  592  :  1
# Cluster  593  :  1
# Cluster  594  :  1
# Cluster  595  :  1
# Cluster  596  :  2
# Cluster  597  :  1
# Cluster  598  :  1
# Cluster  599  :  1
# Cluster  600  :  14
# Cluster  601  :  1
# Cluster  602  :  1
# Cluster  603  :  2
# Cluster  604  :  4
# Cluster  605  :  1
# Cluster  606  :  1
# Cluster  607  :  9
# Cluster  608  :  4
# Cluster  609  :  3
# Cluster  610  :  4
# Cluster  611  :  3
# Cluster  612  :  1
# Cluster  613  :  14
# Cluster  614  :  1
# Cluster  615  :  11
# Cluster  616  :  1
# Cluster  617  :  4
# Cluster  618  :  2
# Cluster  619  :  2
# Cluster  620  :  1
# Cluster  621  :  1
# Cluster  622  :  1
# Cluster  623  :  4
# Cluster  624  :  1
# Cluster  625  :  6
# Cluster  626  :  1
# Cluster  627  :  3
# Cluster  628  :  1
# Cluster  629  :  1
# Cluster  630  :  3
# Cluster  631  :  1
# Cluster  632  :  5
# Cluster  633  :  6
# Cluster  634  :  2
# Cluster  635  :  5
# Cluster  636  :  1
# Cluster  637  :  2
# Cluster  638  :  1
# Cluster  639  :  1
# Cluster  640  :  1
# Cluster  641  :  2
# Cluster  642  :  1
# Cluster  643  :  1
# Cluster  644  :  6
# Cluster  645  :  7
# Cluster  646  :  5
# Cluster  647  :  3
# Cluster  648  :  2
# Cluster  649  :  2
# Cluster  650  :  1
# Cluster  651  :  21
# Cluster  652  :  1
# Cluster  653  :  5
# Cluster  654  :  1
# Cluster  655  :  1
# Cluster  656  :  1
# Cluster  657  :  2
# Cluster  658  :  2
# Cluster  659  :  2
# Cluster  660  :  1
# Cluster  661  :  1
# Cluster  662  :  1
# Cluster  663  :  2
# Cluster  664  :  5
# Cluster  665  :  2
# Cluster  666  :  1
# Cluster  667  :  1
# Cluster  668  :  2
# Cluster  669  :  4
# Cluster  670  :  1
# Cluster  671  :  1
# Cluster  672  :  2
# Cluster  673  :  4
# Cluster  674  :  11
# Cluster  675  :  7
# Cluster  676  :  1
# Cluster  677  :  4
# Cluster  678  :  1
# Cluster  679  :  3
# Cluster  680  :  1
# Cluster  681  :  1
# Cluster  682  :  2
# Cluster  683  :  2
# Cluster  684  :  1
# Cluster  685  :  1
# Cluster  686  :  1
# Cluster  687  :  1
# Cluster  688  :  1
# Cluster  689  :  1
# Cluster  690  :  3
# Cluster  691  :  1
# Cluster  692  :  1
# Cluster  693  :  3
# Cluster  694  :  3
# Cluster  695  :  3
# Cluster  696  :  2
# Cluster  697  :  2
# Cluster  698  :  1
# Cluster  699  :  2
# Cluster  700  :  1
# Cluster  701  :  2
# Cluster  702  :  7
# Cluster  703  :  1
# Cluster  704  :  1
# Cluster  705  :  1
# Cluster  706  :  5
# Cluster  707  :  1
# Cluster  708  :  1
# Cluster  709  :  3
# Cluster  710  :  1
# Cluster  711  :  8
# Cluster  712  :  2
# Cluster  713  :  18
# Cluster  714  :  3
# Cluster  715  :  1
# Cluster  716  :  1
# Cluster  717  :  1
# Cluster  718  :  1
# Cluster  719  :  2
# Cluster  720  :  4
# Cluster  721  :  3
# Cluster  722  :  1
# Cluster  723  :  1
# Cluster  724  :  3
# Cluster  725  :  2
# Cluster  726  :  1
# Cluster  727  :  1
# Cluster  728  :  1
# Cluster  729  :  1
# Cluster  730  :  1
# Cluster  731  :  1
# Cluster  732  :  2
# Cluster  733  :  1
# Cluster  734  :  1
# Cluster  735  :  1
# Cluster  736  :  2
# Cluster  737  :  6
# Cluster  738  :  5
# Cluster  739  :  1
# Cluster  740  :  3
# Cluster  741  :  1
# Cluster  742  :  3
# Cluster  743  :  1
# Cluster  744  :  7
# Cluster  745  :  1
# Cluster  746  :  6
# Cluster  747  :  1
# Cluster  748  :  3
# Cluster  749  :  1
# Cluster  750  :  1
# Cluster  751  :  14
# Cluster  752  :  4
# Cluster  753  :  1
# Cluster  754  :  1
# Cluster  755  :  1
# Cluster  756  :  4
# Cluster  757  :  7
# Cluster  758  :  1
# Cluster  759  :  2
# Cluster  760  :  1
# Cluster  761  :  4
# Cluster  762  :  13
# Cluster  763  :  10
# Cluster  764  :  10
# Cluster  765  :  4
# Cluster  766  :  1
# Cluster  767  :  1
# Cluster  768  :  5
# Cluster  769  :  1
# Cluster  770  :  1
# Cluster  771  :  3
# Cluster  772  :  3
# Cluster  773  :  11
# Cluster  774  :  1
# Cluster  775  :  4
# Cluster  776  :  3
# Cluster  777  :  8
# Cluster  778  :  2
# Cluster  779  :  8
# Cluster  780  :  1
# Cluster  781  :  1
# Cluster  782  :  2
# Cluster  783  :  2
# Cluster  784  :  1
# Cluster  785  :  1
# Cluster  786  :  1
# Cluster  787  :  2
# Cluster  788  :  3
# Cluster  789  :  4
# Cluster  790  :  2
# Cluster  791  :  4
# Cluster  792  :  3
# Cluster  793  :  1
# Cluster  794  :  3
# Cluster  795  :  3
# Cluster  796  :  5
# Cluster  797  :  2
# Cluster  798  :  1
# Cluster  799  :  1
# Cluster  800  :  1
# Cluster  801  :  4
# Cluster  802  :  5
# Cluster  803  :  10
# Cluster  804  :  1
# Cluster  805  :  2
# Cluster  806  :  1
# Cluster  807  :  1
# Cluster  808  :  1
# Cluster  809  :  1
# Cluster  810  :  6
# Cluster  811  :  8
# Cluster  812  :  1
# Cluster  813  :  2
# Cluster  814  :  4
# Cluster  815  :  3
# Cluster  816  :  2
# Cluster  817  :  2
# Cluster  818  :  1
# Cluster  819  :  1
# Cluster  820  :  1
# Cluster  821  :  11
# Cluster  822  :  1
# Cluster  823  :  1
# Cluster  824  :  5
# Cluster  825  :  1
# Cluster  826  :  1
# Cluster  827  :  3
# Cluster  828  :  6
# Cluster  829  :  1
# Cluster  830  :  1
# Cluster  831  :  6
# Cluster  832  :  1
# Cluster  833  :  1
# Cluster  834  :  1
# Cluster  835  :  1
# Cluster  836  :  1
# Cluster  837  :  1
# Cluster  838  :  2
# Cluster  839  :  2
# Cluster  840  :  3
# Cluster  841  :  1
# Cluster  842  :  3
# Cluster  843  :  2
# Cluster  844  :  2
# Cluster  845  :  1
# Cluster  846  :  6
# Cluster  847  :  1
# Cluster  848  :  9
# Cluster  849  :  1
# Cluster  850  :  3
# Cluster  851  :  5
# Cluster  852  :  1
# Cluster  853  :  1
# Cluster  854  :  2
# Cluster  855  :  1
# Cluster  856  :  2
# Cluster  857  :  6
# Cluster  858  :  2
# Cluster  859  :  1
# Cluster  860  :  1
# Cluster  861  :  1
# Cluster  862  :  3
# Cluster  863  :  5
# Cluster  864  :  8
# Cluster  865  :  1
# Cluster  866  :  1
# Cluster  867  :  1
# Cluster  868  :  4
# Cluster  869  :  2
# Cluster  870  :  1
# Cluster  871  :  1
# Cluster  872  :  7
# Cluster  873  :  1
# Cluster  874  :  1
# Cluster  875  :  1
# Cluster  876  :  2
# Cluster  877  :  2
# Cluster  878  :  3
# Cluster  879  :  1
# Cluster  880  :  4
# Cluster  881  :  2
# Cluster  882  :  1
# Cluster  883  :  1
# Cluster  884  :  6
# Cluster  885  :  1
# Cluster  886  :  3
# Cluster  887  :  1
# Cluster  888  :  3
# Cluster  889  :  1
# Cluster  890  :  2
# Cluster  891  :  1
# Cluster  892  :  1
# Cluster  893  :  1
# Cluster  894  :  2
# Cluster  895  :  1
# Cluster  896  :  3
# Cluster  897  :  2
# Cluster  898  :  1
# Cluster  899  :  2
# Cluster  900  :  1
# Cluster  901  :  4
# Cluster  902  :  6
# Cluster  903  :  1
# Cluster  904  :  1
# Cluster  905  :  1
# Cluster  906  :  4
# Cluster  907  :  2
# Cluster  908  :  2
# Cluster  909  :  25
# Cluster  910  :  2
# Cluster  911  :  3
# Cluster  912  :  2
# Cluster  913  :  1
# Cluster  914  :  1
# Cluster  915  :  1
# Cluster  916  :  1
# Cluster  917  :  4
# Cluster  918  :  1
# Cluster  919  :  2
# Cluster  920  :  1
# Cluster  921  :  2
# Cluster  922  :  5
# Cluster  923  :  1
# Cluster  924  :  1
# Cluster  925  :  1
# Cluster  926  :  1
# Cluster  927  :  6
# Cluster  928  :  1
# Cluster  929  :  1
# Cluster  930  :  2
# Cluster  931  :  1
# Cluster  932  :  3
# Cluster  933  :  2
# Cluster  934  :  1
# Cluster  935  :  1
# Cluster  936  :  3
# Cluster  937  :  1
# Cluster  938  :  1
# Cluster  939  :  1
# Cluster  940  :  1
# Cluster  941  :  1
# Cluster  942  :  2
# Cluster  943  :  1
# Cluster  944  :  1
# Cluster  945  :  1
# Cluster  946  :  1
# Cluster  947  :  1
# Cluster  948  :  1
# Cluster  949  :  3
# Cluster  950  :  1
# Cluster  951  :  2
# Cluster  952  :  3
# Cluster  953  :  8
# Cluster  954  :  3
# Cluster  955  :  1
# Cluster  956  :  3
# Cluster  957  :  1
# Cluster  958  :  1
# Cluster  959  :  3
# Cluster  960  :  1
# Cluster  961  :  6
# Cluster  962  :  1
# Cluster  963  :  3
# Cluster  964  :  2
# Cluster  965  :  1
# Cluster  966  :  1
# Cluster  967  :  1
# Cluster  968  :  1
# Cluster  969  :  1
# Cluster  970  :  1
# Cluster  971  :  1
# Cluster  972  :  2
# Cluster  973  :  3
# Cluster  974  :  1
# Cluster  975  :  1
# Cluster  976  :  2
# Cluster  977  :  3
# Cluster  978  :  5
# Cluster  979  :  1
# Cluster  980  :  1
# Cluster  981  :  7
# Cluster  982  :  2
# Cluster  983  :  1
# Cluster  984  :  2
# Cluster  985  :  1
# Cluster  986  :  1
# Cluster  987  :  8
# Cluster  988  :  3
# Cluster  989  :  7
# Cluster  990  :  1
# Cluster  991  :  4
# Cluster  992  :  3
# Cluster  993  :  1
# Cluster  994  :  1
# Cluster  995  :  1
# Cluster  996  :  1
# Cluster  997  :  1
# Cluster  998  :  1
# Cluster  999  :  3
# Cluster  1000  :  1
# Cluster  1001  :  1
# Cluster  1002  :  1
# Cluster  1003  :  5
# Cluster  1004  :  9
# Cluster  1005  :  1
# Cluster  1006  :  2
# Cluster  1007  :  2
# Cluster  1008  :  4
# Cluster  1009  :  3
# Cluster  1010  :  6
# Cluster  1011  :  1
# Cluster  1012  :  1
# Cluster  1013  :  1
# Cluster  1014  :  1
# Cluster  1015  :  1
# Cluster  1016  :  6
# Cluster  1017  :  1
# Cluster  1018  :  1
# Cluster  1019  :  1
# Cluster  1020  :  4
# Cluster  1021  :  1
# Cluster  1022  :  3
# Cluster  1023  :  4
# Cluster  1024  :  2
# Cluster  1025  :  1
# Cluster  1026  :  3
# Cluster  1027  :  1
# Cluster  1028  :  1
# Cluster  1029  :  1
# Cluster  1030  :  3
# Cluster  1031  :  1
# Cluster  1032  :  1
# Cluster  1033  :  1
# Cluster  1034  :  6
# Cluster  1035  :  2
# Cluster  1036  :  1
# Cluster  1037  :  1
# Cluster  1038  :  2
# Cluster  1039  :  2
# Cluster  1040  :  1
# Cluster  1041  :  1
# Cluster  1042  :  1
# Cluster  1043  :  2
# Cluster  1044  :  5
# Cluster  1045  :  1
# Cluster  1046  :  2
# Cluster  1047  :  1
# Cluster  1048  :  3
# Cluster  1049  :  1
# Cluster  1050  :  4
# Cluster  1051  :  1
# Cluster  1052  :  3
# Cluster  1053  :  1
# Cluster  1054  :  1
# Cluster  1055  :  1
# Cluster  1056  :  1
# Cluster  1057  :  4
# Cluster  1058  :  1
# Cluster  1059  :  2
# Cluster  1060  :  1
# Cluster  1061  :  1
# Cluster  1062  :  1
# Cluster  1063  :  4
# Cluster  1064  :  1
# Cluster  1065  :  1
# Cluster  1066  :  1
# Cluster  1067  :  2
# Cluster  1068  :  1
# Cluster  1069  :  1
# Cluster  1070  :  1
# Cluster  1071  :  1
# Cluster  1072  :  1
# Cluster  1073  :  3
# Cluster  1074  :  2
# Cluster  1075  :  1
# Cluster  1076  :  1
# Cluster  1077  :  2
# Cluster  1078  :  1
# Cluster  1079  :  1
# Cluster  1080  :  5
# Cluster  1081  :  1
# Cluster  1082  :  2
# Cluster  1083  :  4
# Cluster  1084  :  1
# Cluster  1085  :  1
# Cluster  1086  :  1
# Cluster  1087  :  3
# Cluster  1088  :  1
# Cluster  1089  :  1
# Cluster  1090  :  1
# Cluster  1091  :  2
# Cluster  1092  :  3
# Cluster  1093  :  1
# Cluster  1094  :  1
# Cluster  1095  :  1
# Cluster  1096  :  1
# Cluster  1097  :  1
# Cluster  1098  :  6
# Cluster  1099  :  1
# Cluster  1100  :  1
# Cluster  1101  :  2
# Cluster  1102  :  1
# Cluster  1103  :  1
# Cluster  1104  :  1
# Cluster  1105  :  2
# Cluster  1106  :  1
# Cluster  1107  :  2
# Cluster  1108  :  2
# Cluster  1109  :  1
# Cluster  1110  :  1
# Cluster  1111  :  7
# Cluster  1112  :  1
# Cluster  1113  :  3
# Cluster  1114  :  1
# Cluster  1115  :  4
# Cluster  1116  :  3
# Cluster  1117  :  2
# Cluster  1118  :  1
# Cluster  1119  :  2
# Cluster  1120  :  3
# Cluster  1121  :  1
# Cluster  1122  :  5
# Cluster  1123  :  2
# Cluster  1124  :  1
# Cluster  1125  :  6
# Cluster  1126  :  1
# Cluster  1127  :  1
# Cluster  1128  :  1
# Cluster  1129  :  1
# Cluster  1130  :  1
# Cluster  1131  :  5
# Cluster  1132  :  2
# Cluster  1133  :  1
# Cluster  1134  :  6
# Cluster  1135  :  8
# Cluster  1136  :  3
# Cluster  1137  :  1
# Cluster  1138  :  9
# Cluster  1139  :  1
# Cluster  1140  :  1
# Cluster  1141  :  1
# Cluster  1142  :  3
# Cluster  1143  :  1
# Cluster  1144  :  3
# Cluster  1145  :  1
# Cluster  1146  :  2
# Cluster  1147  :  1
# Cluster  1148  :  1
# Cluster  1149  :  1
# Cluster  1150  :  1
# Cluster  1151  :  1
# Cluster  1152  :  1
# Cluster  1153  :  1
# Cluster  1154  :  2
# Cluster  1155  :  13
# Cluster  1156  :  1
# Cluster  1157  :  1
# Cluster  1158  :  1
# Cluster  1159  :  4
# Cluster  1160  :  2
# Cluster  1161  :  2
# Cluster  1162  :  3
# Cluster  1163  :  2
# Cluster  1164  :  1
# Cluster  1165  :  1
# Cluster  1166  :  1
# Cluster  1167  :  3
# Cluster  1168  :  1
# Cluster  1169  :  1
# Cluster  1170  :  1
# Cluster  1171  :  1
# Cluster  1172  :  2
# Cluster  1173  :  1
# Cluster  1174  :  1
# Cluster  1175  :  1
# Cluster  1176  :  1
# Cluster  1177  :  1
# Cluster  1178  :  1
# Cluster  1179  :  2
# Cluster  1180  :  2
# Cluster  1181  :  1
# Cluster  1182  :  1
# Cluster  1183  :  2
# Cluster  1184  :  1
# Cluster  1185  :  1
# Cluster  1186  :  1
# Cluster  1187  :  1
# Cluster  1188  :  1
# Cluster  1189  :  2
# Cluster  1190  :  2
# Cluster  1191  :  2
# Cluster  1192  :  1
# Cluster  1193  :  1
# Cluster  1194  :  2
# Cluster  1195  :  2
# Cluster  1196  :  5
# Cluster  1197  :  1
# Cluster  1198  :  1
# Cluster  1199  :  1
# Cluster  1200  :  2
# Cluster  1201  :  1
# Cluster  1202  :  7
# Cluster  1203  :  2
# Cluster  1204  :  1
# Cluster  1205  :  2
# Cluster  1206  :  1
# Cluster  1207  :  1
# Cluster  1208  :  1
# Cluster  1209  :  4
# Cluster  1210  :  2
# Cluster  1211  :  1
# Cluster  1212  :  1
# Cluster  1213  :  1
# Cluster  1214  :  1
# Cluster  1215  :  1
# Cluster  1216  :  2
# Cluster  1217  :  1
# Cluster  1218  :  2
# Cluster  1219  :  1
# Cluster  1220  :  1
# Cluster  1221  :  1
# Cluster  1222  :  1
# Cluster  1223  :  1
# Cluster  1224  :  4
# Cluster  1225  :  1
# Cluster  1226  :  1
# Cluster  1227  :  3
# Cluster  1228  :  6
# Cluster  1229  :  2
# Cluster  1230  :  2
# Cluster  1231  :  1
# Cluster  1232  :  1
# Cluster  1233  :  2
# Cluster  1234  :  1
# Cluster  1235  :  2
# Cluster  1236  :  1
# Cluster  1237  :  1
# Cluster  1238  :  1
# Cluster  1239  :  1
# Cluster  1240  :  1
# Cluster  1241  :  4
# Cluster  1242  :  1
# Cluster  1243  :  2
# Cluster  1244  :  1
# Cluster  1245  :  2
# Cluster  1246  :  5
# Cluster  1247  :  3
# Cluster  1248  :  2
# Cluster  1249  :  1
# Cluster  1250  :  3
# Cluster  1251  :  2
# Cluster  1252  :  3
# Cluster  1253  :  1
# Cluster  1254  :  1
# Cluster  1255  :  1
# Cluster  1256  :  1
# Cluster  1257  :  1
# Cluster  1258  :  1
# Cluster  1259  :  2
# Cluster  1260  :  1
# Cluster  1261  :  2
# Cluster  1262  :  2
# Cluster  1263  :  3
# Cluster  1264  :  1
# Cluster  1265  :  1
# Cluster  1266  :  1
# Cluster  1267  :  1
# Cluster  1268  :  1
# Cluster  1269  :  1
# Cluster  1270  :  2
# Cluster  1271  :  3
# Cluster  1272  :  1
# Cluster  1273  :  1
# Cluster  1274  :  5
# Cluster  1275  :  2
# Cluster  1276  :  1
# Cluster  1277  :  1
# Cluster  1278  :  1
# Cluster  1279  :  1
# Cluster  1280  :  1
# Cluster  1281  :  1
# Cluster  1282  :  1
# Cluster  1283  :  1
# Cluster  1284  :  4
# Cluster  1285  :  6
# Cluster  1286  :  1
# Cluster  1287  :  3
# Cluster  1288  :  2
# Cluster  1289  :  2
# Cluster  1290  :  3
# Cluster  1291  :  1
# Cluster  1292  :  1
# Cluster  1293  :  3
# Cluster  1294  :  3
# Cluster  1295  :  1
# Cluster  1296  :  3
# Cluster  1297  :  1
# Cluster  1298  :  1
# Cluster  1299  :  5
# Cluster  1300  :  2
# Cluster  1301  :  1
# Cluster  1302  :  1
# Cluster  1303  :  3
# Cluster  1304  :  2
# Cluster  1305  :  1
# Cluster  1306  :  1
# Cluster  1307  :  1
# Cluster  1308  :  1
# Cluster  1309  :  1
# Cluster  1310  :  2
# Cluster  1311  :  1
# Cluster  1312  :  1
# Cluster  1313  :  1
# Cluster  1314  :  1
# Cluster  1315  :  1
# Cluster  1316  :  2
# Cluster  1317  :  2
# Cluster  1318  :  4
# Cluster  1319  :  1
# Cluster  1320  :  5
# Cluster  1321  :  1
# Cluster  1322  :  1
# Cluster  1323  :  3
# Cluster  1324  :  2
# Cluster  1325  :  2
# Cluster  1326  :  1
# Cluster  1327  :  3
# Cluster  1328  :  1
# Cluster  1329  :  2
# Cluster  1330  :  5
# Cluster  1331  :  1
# Cluster  1332  :  1
# Cluster  1333  :  2
# Cluster  1334  :  1
# Cluster  1335  :  1
# Cluster  1336  :  2
# Cluster  1337  :  1
# Cluster  1338  :  2
# Cluster  1339  :  1
# Cluster  1340  :  2
# Cluster  1341  :  2
# Cluster  1342  :  1
# Cluster  1343  :  2
# Cluster  1344  :  1
# Cluster  1345  :  3
# Cluster  1346  :  1
# Cluster  1347  :  1
# Cluster  1348  :  1
# Cluster  1349  :  1
# Cluster  1350  :  2
# Cluster  1351  :  3
# Cluster  1352  :  1
# Cluster  1353  :  2
# Cluster  1354  :  6
# Cluster  1355  :  10
# Cluster  1356  :  1
# Cluster  1357  :  2
# Cluster  1358  :  1
# Cluster  1359  :  2
# Cluster  1360  :  1
# Cluster  1361  :  1
# Cluster  1362  :  1
# Cluster  1363  :  1
# Cluster  1364  :  1
# Cluster  1365  :  5
# Cluster  1366  :  1
# Cluster  1367  :  1
# Cluster  1368  :  1
# Cluster  1369  :  1
# Cluster  1370  :  4
# Cluster  1371  :  2
# Cluster  1372  :  1
# Cluster  1373  :  1
# Cluster  1374  :  1
# Cluster  1375  :  2
# Cluster  1376  :  1
# Cluster  1377  :  1
# Cluster  1378  :  1
# Cluster  1379  :  1
# Cluster  1380  :  5
# Cluster  1381  :  2
# Cluster  1382  :  1
# Cluster  1383  :  3
# Cluster  1384  :  1
# Cluster  1385  :  1
# Cluster  1386  :  1
# Cluster  1387  :  2
# Cluster  1388  :  1
# Cluster  1389  :  1
# Cluster  1390  :  1
# Cluster  1391  :  1
# Cluster  1392  :  2
# Cluster  1393  :  3
# Cluster  1394  :  3
# Cluster  1395  :  1
# Cluster  1396  :  1
# Cluster  1397  :  1
# Cluster  1398  :  3
# Cluster  1399  :  3
# Cluster  1400  :  1
# Cluster  1401  :  1
# Cluster  1402  :  1
# Cluster  1403  :  1
# Cluster  1404  :  1
# Cluster  1405  :  1
# Cluster  1406  :  1
# Cluster  1407  :  7
# Cluster  1408  :  4
# Cluster  1409  :  1
# Cluster  1410  :  2
# Cluster  1411  :  1
# Cluster  1412  :  2
# Cluster  1413  :  3
# Cluster  1414  :  1
# Cluster  1415  :  1
# Cluster  1416  :  1
# Cluster  1417  :  1
# Cluster  1418  :  2
# Cluster  1419  :  5
# Cluster  1420  :  1
# Cluster  1421  :  1
# Cluster  1422  :  1
# Cluster  1423  :  2
# Cluster  1424  :  2
# Cluster  1425  :  1
# Cluster  1426  :  1
# Cluster  1427  :  1
# Cluster  1428  :  1
# Cluster  1429  :  3
# Cluster  1430  :  1
# Cluster  1431  :  5
# Cluster  1432  :  1
# Cluster  1433  :  2
# Cluster  1434  :  1
# Cluster  1435  :  3
# Cluster  1436  :  1
# Cluster  1437  :  1
# Cluster  1438  :  1
# Cluster  1439  :  2
# Cluster  1440  :  1
# Cluster  1441  :  2
# Cluster  1442  :  1
# Cluster  1443  :  1
# Cluster  1444  :  3
# Cluster  1445  :  4
# Cluster  1446  :  2
# Cluster  1447  :  3
# Cluster  1448  :  7
# Cluster  1449  :  1
# Cluster  1450  :  2
# Cluster  1451  :  1
# Cluster  1452  :  1
# Cluster  1453  :  1
# Cluster  1454  :  1
# Cluster  1455  :  1
# Cluster  1456  :  1
# Cluster  1457  :  1
# Cluster  1458  :  1
# Cluster  1459  :  2
# Cluster  1460  :  2
# Cluster  1461  :  1
# Cluster  1462  :  1
# Cluster  1463  :  2
# Cluster  1464  :  1
# Cluster  1465  :  2
# Cluster  1466  :  5
# Cluster  1467  :  1
# Cluster  1468  :  1
# Cluster  1469  :  1
# Cluster  1470  :  1
# Cluster  1471  :  1
# Cluster  1472  :  2
# Cluster  1473  :  2
# Cluster  1474  :  1
# Cluster  1475  :  1
# Cluster  1476  :  1
# Cluster  1477  :  5
# Cluster  1478  :  2
# Cluster  1479  :  1
# Cluster  1480  :  2
# Cluster  1481  :  1
# Cluster  1482  :  1
# Cluster  1483  :  1
# Cluster  1484  :  1
# Cluster  1485  :  1
# Cluster  1486  :  1
# Cluster  1487  :  1
# Cluster  1488  :  1
# Cluster  1489  :  2
# Cluster  1490  :  1
# Cluster  1491  :  1
# Cluster  1492  :  2
# Cluster  1493  :  1
# Cluster  1494  :  1
# Cluster  1495  :  1
# Cluster  1496  :  1
# Cluster  1497  :  2
# Cluster  1498  :  3
# Cluster  1499  :  2
# Cluster  1500  :  1
# Cluster  1501  :  1
# Cluster  1502  :  7
# Cluster  1503  :  1
# Cluster  1504  :  1
# Cluster  1505  :  4
# Cluster  1506  :  1
# Cluster  1507  :  3
# Cluster  1508  :  3
# Cluster  1509  :  2
# Cluster  1510  :  1
# Cluster  1511  :  1
# Cluster  1512  :  1
# Cluster  1513  :  1
# Cluster  1514  :  4
# Cluster  1515  :  4
# Cluster  1516  :  4
# Cluster  1517  :  1
# Cluster  1518  :  1
# Cluster  1519  :  1
# Cluster  1520  :  1
# Cluster  1521  :  1
# Cluster  1522  :  1
# Cluster  1523  :  1
# Cluster  1524  :  5
# Cluster  1525  :  1
# Cluster  1526  :  3
# Cluster  1527  :  1
# Cluster  1528  :  1
# Cluster  1529  :  1
# Cluster  1530  :  2
# Cluster  1531  :  2
# Cluster  1532  :  2
# Cluster  1533  :  1
# Cluster  1534  :  1
# Cluster  1535  :  3
# Cluster  1536  :  1
# Cluster  1537  :  1
# Cluster  1538  :  1
# Cluster  1539  :  1
# Cluster  1540  :  3
# Cluster  1541  :  2
# Cluster  1542  :  1
# Cluster  1543  :  2
# Cluster  1544  :  1
# Cluster  1545  :  4
# Cluster  1546  :  4
# Cluster  1547  :  6
# Cluster  1548  :  1
# Cluster  1549  :  1
# Cluster  1550  :  1
# Cluster  1551  :  4
# Cluster  1552  :  1
# Cluster  1553  :  1
# Cluster  1554  :  2
# Cluster  1555  :  2
# Cluster  1556  :  2
# Cluster  1557  :  1
# Cluster  1558  :  1
# Cluster  1559  :  2
# Cluster  1560  :  3
# Cluster  1561  :  1
# Cluster  1562  :  9
# Cluster  1563  :  1
# Cluster  1564  :  1
# Cluster  1565  :  3
# Cluster  1566  :  2
# Cluster  1567  :  2
# Cluster  1568  :  1
# Cluster  1569  :  1
# Cluster  1570  :  2
# Cluster  1571  :  2
# Cluster  1572  :  1
# Cluster  1573  :  1
# Cluster  1574  :  2
# Cluster  1575  :  1
# Cluster  1576  :  1
# Cluster  1577  :  1
# Cluster  1578  :  2
# Cluster  1579  :  1
# Cluster  1580  :  2
# Cluster  1581  :  1
# Cluster  1582  :  1
# Cluster  1583  :  1
# Cluster  1584  :  8
# Cluster  1585  :  1
# Cluster  1586  :  1
# Cluster  1587  :  2
# Cluster  1588  :  2
# Cluster  1589  :  1
# Cluster  1590  :  2
# Cluster  1591  :  2
# Cluster  1592  :  3
# Cluster  1593  :  1
# Cluster  1594  :  2
# Cluster  1595  :  2
# Cluster  1596  :  1
# Cluster  1597  :  1
# Cluster  1598  :  1
# Cluster  1599  :  1
# Cluster  1600  :  1
# Cluster  1601  :  4
# Cluster  1602  :  1
# Cluster  1603  :  2
# Cluster  1604  :  1
# Cluster  1605  :  1
# Cluster  1606  :  1
# Cluster  1607  :  1
# Cluster  1608  :  4
# Cluster  1609  :  2
# Cluster  1610  :  1
# Cluster  1611  :  1
# Cluster  1612  :  3
# Cluster  1613  :  1
# Cluster  1614  :  1
# Cluster  1615  :  1
# Cluster  1616  :  1
# Cluster  1617  :  1
# Cluster  1618  :  1
# Cluster  1619  :  2
# Cluster  1620  :  1
# Cluster  1621  :  1
# Cluster  1622  :  1
# Cluster  1623  :  1
# Cluster  1624  :  2
# Cluster  1625  :  1
# Cluster  1626  :  1
# Cluster  1627  :  1
# Cluster  1628  :  1
# Cluster  1629  :  2
# Cluster  1630  :  1
# Cluster  1631  :  1
# Cluster  1632  :  1
# Cluster  1633  :  1
# Cluster  1634  :  1
# Cluster  1635  :  1
# Cluster  1636  :  1
# Cluster  1637  :  1
# Cluster  1638  :  3
# Cluster  1639  :  3
# Cluster  1640  :  2
# Cluster  1641  :  1
# Cluster  1642  :  5
# Cluster  1643  :  1
# Cluster  1644  :  2
# Cluster  1645  :  1
# Cluster  1646  :  4
# Cluster  1647  :  1
# Cluster  1648  :  1
# Cluster  1649  :  2
# Cluster  1650  :  1
# Cluster  1651  :  1
# Cluster  1652  :  1
# Cluster  1653  :  1
# Cluster  1654  :  1
# Cluster  1655  :  1
# Cluster  1656  :  1
# Cluster  1657  :  1
# Cluster  1658  :  2
# Cluster  1659  :  2
# Cluster  1660  :  3
# Cluster  1661  :  1
# Cluster  1662  :  1
# Cluster  1663  :  1
# Cluster  1664  :  1
# Cluster  1665  :  1
# Cluster  1666  :  1
# Cluster  1667  :  1
# Cluster  1668  :  1
# Cluster  1669  :  1
# Cluster  1670  :  1
# Cluster  1671  :  1
# Cluster  1672  :  4
# Cluster  1673  :  1
# Cluster  1674  :  1
# Cluster  1675  :  2
# Cluster  1676  :  1
# Cluster  1677  :  2
# Cluster  1678  :  2
# Cluster  1679  :  3
# Cluster  1680  :  1
# Cluster  1681  :  2
# Cluster  1682  :  1
# Cluster  1683  :  4
# Cluster  1684  :  1
# Cluster  1685  :  3
# Cluster  1686  :  1
# Cluster  1687  :  4
# Cluster  1688  :  1
# Cluster  1689  :  1
# Cluster  1690  :  1
# Cluster  1691  :  2
# Cluster  1692  :  1
# Cluster  1693  :  1
# Cluster  1694  :  1
# Cluster  1695  :  1
# Cluster  1696  :  1
# Cluster  1697  :  2
# Cluster  1698  :  1
# Cluster  1699  :  1
# Cluster  1700  :  1
# Cluster  1701  :  1
# Cluster  1702  :  1
# Cluster  1703  :  1
# Cluster  1704  :  4
# Cluster  1705  :  1
# Cluster  1706  :  1
# Cluster  1707  :  5
# Cluster  1708  :  1
# Cluster  1709  :  1
# Cluster  1710  :  2
# Cluster  1711  :  2
# Cluster  1712  :  2
# Cluster  1713  :  2
# Cluster  1714  :  2
# Cluster  1715  :  2
# Cluster  1716  :  3
# Cluster  1717  :  2
# Cluster  1718  :  1
# Cluster  1719  :  1
# Cluster  1720  :  1
# Cluster  1721  :  2
# Cluster  1722  :  2
# Cluster  1723  :  1
# Cluster  1724  :  3
# Cluster  1725  :  1
# Cluster  1726  :  1
# Cluster  1727  :  3
# Cluster  1728  :  1
# Cluster  1729  :  3
# Cluster  1730  :  1
# Cluster  1731  :  1
# Cluster  1732  :  1
# Cluster  1733  :  1
# Cluster  1734  :  2
# Cluster  1735  :  1
# Cluster  1736  :  2
# Cluster  1737  :  1
# Cluster  1738  :  1
# Cluster  1739  :  3
# Cluster  1740  :  1
# Cluster  1741  :  1
# Cluster  1742  :  1
# Cluster  1743  :  1
# Cluster  1744  :  1
# Cluster  1745  :  1
# Cluster  1746  :  2
# Cluster  1747  :  2
# Cluster  1748  :  1
# Cluster  1749  :  1
# Cluster  1750  :  3
# Cluster  1751  :  1
# Cluster  1752  :  1
# Cluster  1753  :  1
# Cluster  1754  :  1
# Cluster  1755  :  4
# Cluster  1756  :  2
# Cluster  1757  :  2
# Cluster  1758  :  1
# Cluster  1759  :  1
# Cluster  1760  :  1
# Cluster  1761  :  1
# Cluster  1762  :  1
# Cluster  1763  :  3
# Cluster  1764  :  1
# Cluster  1765  :  1
# Cluster  1766  :  1
# Cluster  1767  :  1
# Cluster  1768  :  1
# Cluster  1769  :  1
# Cluster  1770  :  1
# Cluster  1771  :  1
# Cluster  1772  :  1
# Cluster  1773  :  1
# Cluster  1774  :  3
# Cluster  1775  :  1
# Cluster  1776  :  1
# Cluster  1777  :  1
# Cluster  1778  :  2
# Cluster  1779  :  1
# Cluster  1780  :  1
# Cluster  1781  :  1
# Cluster  1782  :  1
# Cluster  1783  :  2
# Cluster  1784  :  3
# Cluster  1785  :  1
# Cluster  1786  :  1
# Cluster  1787  :  1
# Cluster  1788  :  3
# Cluster  1789  :  2
# Cluster  1790  :  3
# Cluster  1791  :  1
# Cluster  1792  :  2
# Cluster  1793  :  1
# Cluster  1794  :  3
# Cluster  1795  :  1
# Cluster  1796  :  1
# Cluster  1797  :  1
# Cluster  1798  :  1
# Cluster  1799  :  1
# Cluster  1800  :  3
# Cluster  1801  :  2
# Cluster  1802  :  1
# Cluster  1803  :  1
# Cluster  1804  :  2
# Cluster  1805  :  1
# Cluster  1806  :  3
# Cluster  1807  :  1
# Cluster  1808  :  1
# Cluster  1809  :  1
# Cluster  1810  :  1
# Cluster  1811  :  1
# Cluster  1812  :  3
# Cluster  1813  :  2
# Cluster  1814  :  2
# Cluster  1815  :  1
# Cluster  1816  :  1
# Cluster  1817  :  1
# Cluster  1818  :  1
# Cluster  1819  :  1
# Cluster  1820  :  2
# Cluster  1821  :  1
# Cluster  1822  :  2
# Cluster  1823  :  1
# Cluster  1824  :  1
# Cluster  1825  :  1
# Cluster  1826  :  1
# Cluster  1827  :  1
# Cluster  1828  :  1
# Cluster  1829  :  1
# Cluster  1830  :  1
# Cluster  1831  :  2
# Cluster  1832  :  1
# Cluster  1833  :  1
# Cluster  1834  :  3
# Cluster  1835  :  1
# Cluster  1836  :  1
# Cluster  1837  :  3
# Cluster  1838  :  1
# Cluster  1839  :  1
# Cluster  1840  :  3
# Cluster  1841  :  1
# Cluster  1842  :  2
# Cluster  1843  :  1
# Cluster  1844  :  1
# Cluster  1845  :  1
# Cluster  1846  :  2
# Cluster  1847  :  1
# Cluster  1848  :  1
# Cluster  1849  :  1
# Cluster  1850  :  1
# Cluster  1851  :  2
# Cluster  1852  :  1
# Cluster  1853  :  1
# Cluster  1854  :  6
# Cluster  1855  :  1
# Cluster  1856  :  3
# Cluster  1857  :  1
# Cluster  1858  :  1
# Cluster  1859  :  1
# Cluster  1860  :  2
# Cluster  1861  :  1
# Cluster  1862  :  1
# Cluster  1863  :  2
# Cluster  1864  :  1
# Cluster  1865  :  1
# Cluster  1866  :  1
# Cluster  1867  :  4
# Cluster  1868  :  1
# Cluster  1869  :  1
# Cluster  1870  :  1
# Cluster  1871  :  4
# Cluster  1872  :  2
# Cluster  1873  :  1
# Cluster  1874  :  1
# Cluster  1875  :  1
# Cluster  1876  :  1
# Cluster  1877  :  4
# Cluster  1878  :  1
# Cluster  1879  :  1
# Cluster  1880  :  1
# Cluster  1881  :  1
# Cluster  1882  :  1
# Cluster  1883  :  5
# Cluster  1884  :  1
# Cluster  1885  :  1
# Cluster  1886  :  3
# Cluster  1887  :  1
# Cluster  1888  :  1
# Cluster  1889  :  3
# Cluster  1890  :  2
# Cluster  1891  :  1
# Cluster  1892  :  1
# Cluster  1893  :  2
# Cluster  1894  :  4
# Cluster  1895  :  1
# Cluster  1896  :  2
# Cluster  1897  :  4
# Cluster  1898  :  2
# Cluster  1899  :  1
# Cluster  1900  :  2
# Cluster  1901  :  1
# Cluster  1902  :  1
# Cluster  1903  :  1
# Cluster  1904  :  1
# Cluster  1905  :  1
# Cluster  1906  :  1
# Cluster  1907  :  1
# Cluster  1908  :  1
# Cluster  1909  :  1
# Cluster  1910  :  2
# Cluster  1911  :  1
# Cluster  1912  :  3
# Cluster  1913  :  1
# Cluster  1914  :  3
# Cluster  1915  :  3
# Cluster  1916  :  1
# Cluster  1917  :  1
# Cluster  1918  :  2
# Cluster  1919  :  1
# Cluster  1920  :  4
# Cluster  1921  :  3
# Cluster  1922  :  1
# Cluster  1923  :  2
# Cluster  1924  :  4
# Cluster  1925  :  1
# Cluster  1926  :  1
# Cluster  1927  :  1
# Cluster  1928  :  3
# Cluster  1929  :  1
# Cluster  1930  :  1
# Cluster  1931  :  1
# Cluster  1932  :  1
# Cluster  1933  :  1
# Cluster  1934  :  2
# Cluster  1935  :  1
# Cluster  1936  :  1
# Cluster  1937  :  3
# Cluster  1938  :  1
# Cluster  1939  :  1
# Cluster  1940  :  1
# Cluster  1941  :  1
# Cluster  1942  :  1
# Cluster  1943  :  1
# Cluster  1944  :  1
# Cluster  1945  :  1
# Cluster  1946  :  1
# Cluster  1947  :  1
# Cluster  1948  :  1
# Cluster  1949  :  1
# Cluster  1950  :  1
# Cluster  1951  :  2
# Cluster  1952  :  1
# Cluster  1953  :  3
# Cluster  1954  :  1
# Cluster  1955  :  1
# Cluster  1956  :  1
# Cluster  1957  :  1
# Cluster  1958  :  1
# Cluster  1959  :  1
# Cluster  1960  :  1
# Cluster  1961  :  1
# Cluster  1962  :  2
# Cluster  1963  :  1
# Cluster  1964  :  4
# Cluster  1965  :  1
# Cluster  1966  :  1
# Cluster  1967  :  1
# Cluster  1968  :  1
# Cluster  1969  :  2
# Cluster  1970  :  1
# Cluster  1971  :  2
# Cluster  1972  :  1
# Cluster  1973  :  1
# Cluster  1974  :  1
# Cluster  1975  :  1
# Cluster  1976  :  3
# Cluster  1977  :  1
# Cluster  1978  :  2
# Cluster  1979  :  2
# Cluster  1980  :  1
# Cluster  1981  :  1
# Cluster  1982  :  3
# Cluster  1983  :  1
# Cluster  1984  :  1
# Cluster  1985  :  1
# Cluster  1986  :  1
# Cluster  1987  :  1
# Cluster  1988  :  1
# Cluster  1989  :  4
# Cluster  1990  :  1
# Cluster  1991  :  1
# Cluster  1992  :  1
# Cluster  1993  :  1
# Cluster  1994  :  1
# Cluster  1995  :  3
# Cluster  1996  :  1
# Cluster  1997  :  3
# Cluster  1998  :  1
# Cluster  1999  :  1
# Cluster  2000  :  1
# Cluster  2001  :  2
# Cluster  2002  :  3
# Cluster  2003  :  2
# Cluster  2004  :  1
# Cluster  2005  :  1
# Cluster  2006  :  2
# Cluster  2007  :  1
# Cluster  2008  :  1
# Cluster  2009  :  2
# Cluster  2010  :  1
# Cluster  5153  :  1
# Cluster  5154  :  1
# Cluster  5155  :  1
# Cluster  5156  :  1
# Cluster  5157  :  1
# Cluster  5158  :  1
# Cluster  5159  :  1
# Cluster  5160  :  1
# Cluster  5161  :  1
# Cluster  5162  :  1
# Cluster  5163  :  1
# Cluster  5164  :  1
# Cluster  5165  :  1
# Cluster  5166  :  1
# Cluster  5167  :  1
# Cluster  5168  :  1
# Cluster  5169  :  1
# Cluster  5170  :  1
# Cluster  5171  :  1
# Cluster  5172  :  1
# Cluster  5173  :  1
# Cluster  5174  :  1
# Cluster  5175  :  1
# Cluster  5176  :  1
# Cluster  5177  :  1
# Cluster  5178  :  1
# Cluster  5179  :  1
# Cluster  5180  :  1
# Cluster  5181  :  1
# Cluster  5182  :  1
# Cluster  5183  :  1
# Cluster  5184  :  1
# Cluster  5185  :  1
# Cluster  5186  :  1
# Cluster  5187  :  1
# Cluster  5188  :  1
# Cluster  5189  :  1
# Cluster  5190  :  1
# Cluster  5191  :  2
# Cluster  5192  :  1
# Cluster  5193  :  1
# Cluster  5194  :  1
# Cluster  5195  :  1
# Cluster  5196  :  1
# Cluster  5197  :  1
# Cluster  5198  :  1
# Cluster  5199  :  1
# Cluster  5200  :  1
# Cluster  5201  :  1
# Cluster  5202  :  1
# Cluster  5203  :  2
# Cluster  5204  :  1
# Cluster  5205  :  1
# Cluster  5206  :  1
# Cluster  5207  :  1
# Cluster  5208  :  1
# Cluster  5209  :  1
# Cluster  5210  :  1
# Total number of vectors:  10098

# %%
#  plot graph to show cluster index vs cluster size of normal clusters

for i in range(0, len(updated_normal_clusters)):
    plt.scatter(i, len(updated_normal_clusters[i]), color='green')

plt.title('Normal Clusters')
plt.xlabel('Cluster Index')
plt.ylabel('Cluster Size')
plt.show()

# %% [markdown]
# ` Reclustering covid vectors `

# %%
r = 1000

updated_covid_clusters = []  # list of clusters

updated_cluster=[]
check = []
for i in range(0, len(updated_covid_vectors)-1):
    updated_cluster = []
    if updated_covid_vectors[i] not in check:
        updated_cluster.append(updated_covid_vectors[i])
        check.append(updated_covid_vectors[i])
    else:
        continue
    for j in range(i+1, len(updated_covid_vectors)):

        if euclidean_distance(updated_covid_vectors[i], updated_covid_vectors[j]) <= r:
            if updated_covid_vectors[j] not in check:
                updated_cluster.append(updated_covid_vectors[j])
                check.append(updated_covid_vectors[j])

    updated_covid_clusters.append(updated_cluster)

# %%
# print the clusters
sum=0
for i in range(0, len(updated_covid_clusters)):
    print("Cluster ", i+1, " : ", len(updated_covid_clusters[i]))
    sum+=len(updated_covid_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Cluster  1  :  2
# Cluster  2  :  2
# Cluster  3  :  1
# Cluster  4  :  1
# Cluster  5  :  1
# Cluster  6  :  1
# Cluster  7  :  1
# Cluster  8  :  2
# Cluster  9  :  1
# Cluster  10  :  1
# Cluster  11  :  2
# Cluster  12  :  8
# Cluster  13  :  1
# Cluster  14  :  1
# Cluster  15  :  3
# Cluster  16  :  1
# Cluster  17  :  1
# Cluster  18  :  1
# Cluster  19  :  1
# Cluster  20  :  3
# Cluster  21  :  1
# Cluster  22  :  1
# Cluster  23  :  1
# Cluster  24  :  1
# Cluster  25  :  1
# Cluster  26  :  1
# Cluster  922  :  1
# Cluster  923  :  1
# Cluster  924  :  1
# Cluster  925  :  1
# Cluster  926  :  1
# Cluster  927  :  1
# Cluster  928  :  1
# Cluster  929  :  1
# Cluster  930  :  1
# Cluster  931  :  1
# Cluster  932  :  1
# Cluster  933  :  1
# Cluster  934  :  1
# Cluster  935  :  1
# Cluster  936  :  1
# Cluster  937  :  1
# Cluster  938  :  1
# Cluster  939  :  1
# Cluster  940  :  1
# Cluster  941  :  1
# Cluster  942  :  2
# Cluster  943  :  1
# Cluster  944  :  1
# Cluster  945  :  1
# Cluster  946  :  1
# Cluster  947  :  1
# Cluster  948  :  1
# Cluster  949  :  3
# Cluster  950  :  1
# Cluster  951  :  1
# Cluster  952  :  1
# Cluster  953  :  1
# Cluster  954  :  1
# Cluster  955  :  2
# Cluster  956  :  1
# Cluster  957  :  1
# Cluster  958  :  1
# Cluster  959  :  1
# Cluster  960  :  1
# Cluster  961  :  1
# Cluster  962  :  1
# Cluster  963  :  2
# Cluster  964  :  1
# Cluster  965  :  3
# Cluster  966  :  1
# Cluster  967  :  1
# Cluster  968  :  1
# Cluster  969  :  1
# Cluster  970  :  2
# Cluster  971  :  1
# Cluster  972  :  2
# Cluster  973  :  2
# Cluster  974  :  1
# Cluster  975  :  2
# Cluster  976  :  2
# Cluster  977  :  1
# Cluster  978  :  2
# Cluster  979  :  1
# Cluster  980  :  1
# Cluster  981  :  1
# Cluster  982  :  1
# Cluster  983  :  1
# Cluster  984  :  1
# Cluster  985  :  1
# Cluster  986  :  1
# Cluster  987  :  1
# Cluster  988  :  1
# Cluster  989  :  1
# Cluster  990  :  1
# Cluster  991  :  1
# Cluster  992  :  1
# Cluster  993  :  1
# Cluster  994  :  3
# Cluster  995  :  5
# Cluster  996  :  7
# Cluster  997  :  2
# Cluster  998  :  2
# Cluster  999  :  1
# Cluster  1000  :  1
# Cluster  1001  :  1
# Cluster  1002  :  1
# Cluster  1003  :  2
# Cluster  1004  :  1
# Cluster  1005  :  1
# Cluster  1006  :  1
# Cluster  1007  :  1
# Cluster  1008  :  1
# Cluster  1009  :  1
# Cluster  1010  :  1
# Cluster  1011  :  1
# Cluster  1012  :  1
# Cluster  1013  :  1
# Cluster  1014  :  1
# Cluster  1015  :  5
# Cluster  1016  :  2
# Cluster  1017  :  2
# Cluster  1018  :  5
# Cluster  1019  :  2
# Cluster  1020  :  23
# Cluster  1021  :  1
# Cluster  1022  :  1
# Cluster  1023  :  1
# Cluster  1024  :  1
# Cluster  1025  :  1
# Cluster  1026  :  2
# Cluster  1027  :  2
# Cluster  1028  :  1
# Cluster  1029  :  1
# Cluster  1030  :  1
# Cluster  1031  :  3
# Cluster  1032  :  3
# Cluster  1033  :  9
# Cluster  1034  :  1
# Cluster  1035  :  1
# Cluster  1036  :  1
# Cluster  1037  :  2
# Cluster  1038  :  1
# Cluster  1039  :  1
# Cluster  1040  :  1
# Cluster  1041  :  1
# Cluster  1042  :  2
# Cluster  1043  :  1
# Cluster  1044  :  1
# Cluster  1045  :  4
# Cluster  1046  :  1
# Cluster  1047  :  1
# Cluster  1048  :  2
# Cluster  1049  :  1
# Cluster  1050  :  3
# Cluster  1051  :  1
# Cluster  1052  :  9
# Cluster  1053  :  1
# Cluster  1054  :  6
# Cluster  1055  :  1
# Cluster  1056  :  2
# Cluster  1057  :  2
# Cluster  1058  :  1
# Cluster  1059  :  1
# Cluster  1060  :  1
# Cluster  1061  :  1
# Cluster  1062  :  1
# Cluster  1063  :  2
# Cluster  1064  :  1
# Cluster  1065  :  1
# Cluster  1066  :  2
# Cluster  1067  :  1
# Cluster  1068  :  3
# Cluster  1069  :  1
# Cluster  1070  :  2
# Cluster  1071  :  1
# Cluster  1072  :  4
# Cluster  1073  :  2
# Cluster  1074  :  1
# Cluster  1075  :  1
# Cluster  1076  :  3
# Cluster  1077  :  1
# Cluster  1078  :  1
# Cluster  1079  :  1
# Cluster  1080  :  1
# Cluster  1081  :  1
# Cluster  1082  :  1
# Cluster  1083  :  1
# Cluster  1084  :  9
# Cluster  1085  :  2
# Cluster  1086  :  4
# Cluster  1087  :  1
# Cluster  1088  :  1
# Cluster  1089  :  2
# Cluster  1090  :  1
# Cluster  1091  :  4
# Cluster  1092  :  1
# Cluster  1093  :  1
# Cluster  1094  :  1
# Cluster  1095  :  1
# Cluster  1096  :  1
# Cluster  1097  :  1
# Cluster  1098  :  2
# Cluster  1099  :  1
# Cluster  1100  :  1
# Cluster  1101  :  1
# Cluster  1102  :  1
# Cluster  1103  :  1
# Cluster  1104  :  1
# Cluster  1105  :  3
# Cluster  1106  :  1
# Cluster  1107  :  1
# Cluster  1108  :  1
# Cluster  1109  :  1
# Cluster  1110  :  1
# Cluster  1111  :  1
# Cluster  1112  :  2
# Cluster  1113  :  1
# Cluster  1114  :  1
# Cluster  1115  :  2
# Cluster  1116  :  1
# Cluster  1117  :  1
# Cluster  1118  :  1
# Cluster  1119  :  1
# Cluster  1120  :  1
# Cluster  1121  :  1
# Cluster  1122  :  2
# Cluster  1123  :  1
# Cluster  1124  :  1
# Cluster  1125  :  1
# Cluster  1126  :  1
# Cluster  1127  :  2
# Cluster  1128  :  3
# Cluster  1129  :  1
# Cluster  1130  :  1
# Cluster  1131  :  1
# Cluster  1132  :  1
# Cluster  1133  :  1
# Cluster  1134  :  1
# Cluster  1135  :  1
# Cluster  1136  :  1
# Cluster  1137  :  1
# Cluster  1138  :  2
# Cluster  1139  :  1
# Cluster  1140  :  1
# Cluster  1141  :  1
# Cluster  1142  :  1
# Cluster  1143  :  1
# Cluster  1144  :  1
# Cluster  1145  :  1
# Cluster  1146  :  1
# Cluster  1147  :  1
# Cluster  1148  :  1
# Cluster  1149  :  1
# Cluster  1150  :  1
# Cluster  1151  :  1
# Cluster  1152  :  1
# Cluster  1153  :  1
# Cluster  1154  :  1
# Cluster  1155  :  1
# Cluster  1156  :  1
# Cluster  1157  :  1
# Cluster  1158  :  1
# Cluster  1159  :  1
# Cluster  1160  :  1
# Cluster  1161  :  1
# Cluster  1162  :  1
# Cluster  1163  :  1
# Cluster  1164  :  2
# Cluster  1165  :  1
# Cluster  1166  :  1
# Cluster  1167  :  1
# Cluster  1168  :  1
# Cluster  1169  :  2
# Cluster  1170  :  1
# Cluster  1171  :  1
# Cluster  1172  :  1
# Cluster  1173  :  1
# Cluster  1174  :  1
# Cluster  1175  :  1
# Cluster  1176  :  1
# Cluster  1177  :  1
# Cluster  1178  :  1
# Cluster  1179  :  1
# Cluster  1180  :  1
# Cluster  1181  :  2
# Cluster  1182  :  1
# Cluster  1183  :  1
# Cluster  1184  :  1
# Cluster  1185  :  1
# Cluster  1186  :  1
# Cluster  1187  :  1
# Cluster  1188  :  1
# Cluster  1189  :  3
# Cluster  1190  :  1
# Cluster  1191  :  1
# Cluster  1192  :  1
# Cluster  1193  :  1
# Cluster  1194  :  1
# Cluster  1195  :  1
# Cluster  1196  :  1
# Cluster  1197  :  1
# Cluster  1198  :  1
# Cluster  1199  :  1
# Cluster  1200  :  1
# Cluster  1201  :  2
# Cluster  1202  :  1
# Cluster  1203  :  1
# Cluster  1204  :  1
# Cluster  1205  :  1
# Cluster  1206  :  1
# Cluster  1207  :  1
# Cluster  1208  :  1
# Cluster  1209  :  1
# Cluster  1210  :  1
# Cluster  1211  :  1
# Cluster  1212  :  1
# Cluster  1213  :  1
# Cluster  1214  :  2
# Cluster  1215  :  1
# Cluster  1216  :  1
# Cluster  1217  :  1
# Cluster  1218  :  1
# Cluster  1219  :  1
# Cluster  1220  :  1
# Cluster  1221  :  1
# Cluster  1222  :  1
# Cluster  1223  :  1
# Cluster  1224  :  1
# Cluster  1225  :  2
# Cluster  1226  :  1
# Cluster  1227  :  1
# Cluster  1228  :  2
# Cluster  1229  :  1
# Cluster  1230  :  1
# Cluster  1231  :  1
# Cluster  1232  :  1
# Cluster  1233  :  1
# Cluster  1234  :  1
# Cluster  1235  :  1
# Cluster  1236  :  1
# Cluster  1237  :  1
# Cluster  1238  :  1
# Cluster  1239  :  1
# Cluster  1240  :  1
# Cluster  1241  :  1
# Cluster  1242  :  1
# Cluster  1243  :  1
# Cluster  1244  :  1
# Cluster  1245  :  1
# Cluster  1246  :  4
# Cluster  1247  :  1
# Cluster  1248  :  4
# Cluster  1249  :  1
# Cluster  1250  :  1
# Cluster  1251  :  1
# Cluster  1252  :  1
# Cluster  1253  :  1
# Cluster  1254  :  1
# Cluster  1255  :  1
# Cluster  1256  :  1
# Cluster  1257  :  1
# Cluster  1258  :  1
# Cluster  1259  :  1
# Cluster  1260  :  1
# Cluster  1261  :  1
# Cluster  1262  :  1
# Cluster  1263  :  1
# Cluster  1264  :  1
# Cluster  1265  :  1
# Cluster  1266  :  1
# Cluster  1267  :  1
# Cluster  1268  :  1
# Cluster  1269  :  1
# Cluster  1270  :  1
# Cluster  1271  :  1
# Cluster  1272  :  1
# Cluster  1273  :  1
# Cluster  1274  :  1
# Cluster  1275  :  1
# Cluster  1276  :  1
# Cluster  1277  :  1
# Cluster  1278  :  2
# Cluster  1279  :  1
# Cluster  1280  :  1
# Cluster  1281  :  1
# Cluster  1282  :  1
# Cluster  1283  :  1
# Cluster  1284  :  1
# Cluster  1285  :  1
# Cluster  1286  :  1
# Cluster  1287  :  1
# Cluster  1288  :  1
# Cluster  1289  :  1
# Cluster  1290  :  1
# Cluster  1291  :  1
# Cluster  1292  :  1
# Cluster  1293  :  1
# Cluster  1294  :  1
# Cluster  1295  :  1
# Cluster  1296  :  1
# Cluster  1297  :  1
# Cluster  1298  :  2
# Cluster  1299  :  1
# Cluster  1300  :  1
# Cluster  1301  :  1
# Cluster  1302  :  1
# Cluster  1303  :  1
# Cluster  1304  :  1
# Cluster  1305  :  1
# Cluster  1306  :  1
# Cluster  1307  :  1
# Cluster  1308  :  2
# Cluster  1309  :  1
# Cluster  1310  :  1
# Cluster  1311  :  1
# Cluster  1312  :  1
# Cluster  1313  :  1
# Cluster  1314  :  1
# Cluster  1315  :  3
# Cluster  1316  :  1
# Cluster  1317  :  1
# Cluster  1318  :  1
# Cluster  1319  :  1
# Cluster  1320  :  1
# Cluster  1321  :  1
# Cluster  1322  :  1
# Cluster  1323  :  1
# Cluster  1324  :  1
# Cluster  1325  :  1
# Cluster  1326  :  1
# Cluster  1327  :  1
# Cluster  1328  :  1
# Cluster  1329  :  1
# Cluster  1330  :  1
# Cluster  1331  :  1
# Cluster  1332  :  2
# Cluster  1333  :  1
# Cluster  1334  :  1
# Cluster  1335  :  1
# Cluster  1336  :  1
# Cluster  1337  :  1
# Cluster  1338  :  1
# Cluster  1339  :  1
# Cluster  1340  :  1
# Cluster  1341  :  1
# Cluster  1342  :  1
# Cluster  1343  :  1
# Cluster  1344  :  1
# Cluster  1345  :  1
# Cluster  1346  :  1
# Cluster  1347  :  1
# Cluster  1348  :  1
# Cluster  1349  :  2
# Cluster  1350  :  3
# Cluster  1351  :  2
# Cluster  1352  :  1
# Cluster  1353  :  1
# Cluster  1354  :  1
# Cluster  1355  :  1
# Cluster  1356  :  1
# Cluster  1357  :  2
# Cluster  1358  :  1
# Cluster  1359  :  2
# Cluster  1360  :  1
# Cluster  1361  :  1
# Cluster  1362  :  1
# Cluster  1363  :  1
# Cluster  1364  :  1
# Cluster  1365  :  2
# Cluster  1366  :  2
# Cluster  1367  :  1
# Cluster  1368  :  1
# Cluster  1369  :  3
# Cluster  1370  :  1
# Cluster  1371  :  1
# Cluster  1372  :  1
# Cluster  1373  :  1
# Cluster  1374  :  2
# Cluster  1375  :  1
# Cluster  1376  :  1
# Cluster  1377  :  1
# Cluster  1378  :  1
# Cluster  1379  :  1
# Cluster  1380  :  1
# Cluster  1381  :  2
# Cluster  1382  :  1
# Cluster  1383  :  2
# Cluster  1384  :  1
# Cluster  1385  :  1
# Cluster  1386  :  1
# Cluster  1387  :  2
# Cluster  1388  :  1
# Cluster  1389  :  2
# Cluster  1390  :  1
# Cluster  1391  :  1
# Cluster  1392  :  1
# Cluster  1393  :  1
# Cluster  1394  :  1
# Cluster  1395  :  3
# Cluster  1396  :  1
# Cluster  1397  :  1
# Cluster  1398  :  2
# Cluster  1399  :  1
# Cluster  1400  :  2
# Cluster  1401  :  1
# Cluster  1402  :  2
# Cluster  1403  :  1
# Cluster  1404  :  2
# Cluster  1405  :  1
# Cluster  1406  :  2
# Cluster  1407  :  1
# Cluster  1408  :  6
# Cluster  1409  :  1
# Cluster  1410  :  1
# Cluster  1411  :  1
# Cluster  1412  :  1
# Cluster  1413  :  2
# Cluster  1414  :  1
# Cluster  1415  :  1
# Cluster  1416  :  1
# Cluster  1417  :  1
# Cluster  1418  :  3
# Cluster  1419  :  1
# Cluster  1420  :  2
# Cluster  1421  :  1
# Cluster  1422  :  1
# Cluster  1423  :  1
# Cluster  1424  :  1
# Cluster  1425  :  1
# Cluster  1426  :  1
# Cluster  1427  :  1
# Cluster  1428  :  1
# Cluster  1429  :  1
# Cluster  1430  :  1
# Cluster  1431  :  1
# Cluster  1432  :  1
# Cluster  1433  :  1
# Cluster  1434  :  1
# Cluster  1435  :  1
# Cluster  1436  :  1
# Cluster  1437  :  1
# Cluster  1438  :  1
# Cluster  1439  :  1
# Cluster  1440  :  1
# Cluster  1441  :  1
# Cluster  1442  :  1
# Cluster  1443  :  1
# Cluster  1444  :  1
# Cluster  1445  :  1
# Cluster  1446  :  1
# Cluster  1447  :  1
# Cluster  1448  :  1
# Cluster  1449  :  1
# Cluster  1450  :  1
# Cluster  1451  :  1
# Cluster  1452  :  2
# Cluster  1453  :  1
# Cluster  1454  :  2
# Cluster  1455  :  1
# Cluster  1456  :  1
# Cluster  1457  :  1
# Cluster  1458  :  1
# Cluster  1459  :  1
# Cluster  1460  :  1
# Cluster  1461  :  1
# Cluster  1462  :  1
# Cluster  1463  :  2
# Cluster  1464  :  1
# Cluster  1465  :  1
# Cluster  1466  :  1
# Cluster  1467  :  1
# Cluster  1468  :  1
# Cluster  1469  :  1
# Cluster  1470  :  2
# Cluster  1471  :  1
# Cluster  1472  :  3
# Cluster  1473  :  1
# Cluster  1474  :  1
# Cluster  1475  :  1
# Cluster  1476  :  1
# Cluster  1477  :  1
# Cluster  1478  :  1
# Cluster  1479  :  1
# Cluster  1480  :  1
# Cluster  1481  :  1
# Cluster  1482  :  1
# Cluster  1483  :  1
# Cluster  1484  :  1
# Cluster  1485  :  1
# Cluster  1486  :  1
# Cluster  1487  :  2
# Cluster  1488  :  1
# Cluster  1489  :  1
# Cluster  1490  :  1
# Cluster  1491  :  1
# Cluster  1492  :  1
# Cluster  1493  :  1
# Cluster  1494  :  1
# Cluster  1495  :  1
# Cluster  1496  :  1
# Cluster  1497  :  1
# Cluster  1498  :  1
# Cluster  1499  :  1
# Cluster  1500  :  1
# Cluster  1501  :  1
# Cluster  1502  :  2
# Cluster  1503  :  1
# Cluster  1504  :  1
# Cluster  1505  :  1
# Cluster  1506  :  2
# Cluster  1507  :  1
# Cluster  1508  :  1
# Cluster  1509  :  1
# Cluster  1510  :  1
# Cluster  1511  :  1
# Cluster  1512  :  2
# Cluster  1513  :  3
# Cluster  1514  :  1
# Cluster  1515  :  1
# Cluster  1516  :  1
# Cluster  1517  :  1
# Cluster  1518  :  1
# Cluster  1519  :  1
# Cluster  1520  :  1
# Cluster  1521  :  1
# Cluster  1522  :  1
# Cluster  1523  :  1
# Cluster  1524  :  1
# Cluster  1525  :  1
# Cluster  1526  :  1
# Cluster  1527  :  1
# Cluster  1528  :  6
# Cluster  1529  :  1
# Cluster  1530  :  1
# Cluster  1531  :  1
# Cluster  1532  :  1
# Cluster  1533  :  1
# Cluster  1534  :  2
# Cluster  1535  :  1
# Cluster  1536  :  1
# Cluster  1537  :  1
# Cluster  1538  :  1
# Cluster  1539  :  1
# Cluster  1540  :  1
# Cluster  1541  :  1
# Cluster  1542  :  1
# Cluster  1543  :  1
# Cluster  1544  :  1
# Cluster  1545  :  1
# Cluster  1546  :  1
# Cluster  1547  :  2
# Cluster  1548  :  1
# Cluster  1549  :  1
# Cluster  1550  :  4
# Cluster  1551  :  1
# Cluster  1552  :  1
# Cluster  1553  :  1
# Cluster  1554  :  1
# Cluster  1555  :  1
# Cluster  1556  :  1
# Cluster  1557  :  1
# Cluster  1558  :  1
# Cluster  1559  :  1
# Cluster  1560  :  1
# Cluster  1561  :  1
# Cluster  1562  :  1
# Cluster  1563  :  1
# Cluster  1564  :  1
# Cluster  1565  :  2
# Cluster  1566  :  1
# Cluster  1567  :  1
# Cluster  1568  :  1
# Cluster  1569  :  1
# Cluster  1570  :  1
# Cluster  1571  :  1
# Cluster  1572  :  1
# Cluster  1573  :  1
# Cluster  1574  :  1
# Cluster  1575  :  1
# Cluster  1576  :  1
# Cluster  1577  :  1
# Cluster  1578  :  1
# Cluster  1579  :  1
# Cluster  1580  :  1
# Cluster  1581  :  1
# Cluster  1582  :  1
# Cluster  1583  :  1
# Cluster  1584  :  1
# Cluster  1585  :  1
# Cluster  1586  :  1
# Cluster  1587  :  1
# Cluster  1588  :  1
# Cluster  1589  :  1
# Cluster  1590  :  1
# Cluster  1591  :  1
# Cluster  1592  :  1
# Cluster  1593  :  1
# Cluster  1594  :  1
# Cluster  1595  :  1
# Cluster  1596  :  6
# Cluster  1597  :  1
# Cluster  1598  :  1
# Cluster  1599  :  4
# Cluster  1600  :  1
# Cluster  1601  :  1
# Cluster  1602  :  1
# Cluster  1603  :  1
# Cluster  1604  :  1
# Cluster  1605  :  1
# Cluster  1606  :  1
# Cluster  1607  :  1
# Cluster  1608  :  1
# Cluster  1609  :  1
# Cluster  1610  :  1
# Cluster  1611  :  1
# Cluster  1612  :  1
# Cluster  1613  :  2
# Cluster  1614  :  1
# Cluster  1615  :  1
# Cluster  1616  :  1
# Cluster  1617  :  1
# Cluster  1618  :  1
# Cluster  1619  :  1
# Cluster  1620  :  1
# Cluster  1621  :  1
# Cluster  1622  :  1
# Cluster  1623  :  2
# Cluster  1624  :  2
# Cluster  1625  :  1
# Cluster  1626  :  1
# Cluster  1627  :  1
# Cluster  1628  :  1
# Cluster  1629  :  1
# Cluster  1630  :  1
# Cluster  1631  :  1
# Cluster  1632  :  1
# Cluster  1633  :  1
# Cluster  1634  :  1
# Cluster  1635  :  1
# Cluster  1636  :  1
# Cluster  1637  :  1
# Cluster  1638  :  1
# Cluster  1639  :  1
# Cluster  1640  :  1
# Cluster  1641  :  1
# Cluster  1642  :  1
# Cluster  1643  :  1
# Cluster  1644  :  2
# Cluster  1645  :  1
# Cluster  1646  :  1
# Cluster  1647  :  1
# Cluster  1648  :  1
# Cluster  1649  :  1
# Cluster  1650  :  1
# Cluster  1651  :  1
# Cluster  1652  :  1
# Cluster  1653  :  1
# Cluster  1654  :  1
# Cluster  1655  :  1
# Cluster  1656  :  1
# Cluster  1657  :  1
# Cluster  1658  :  1
# Cluster  1659  :  1
# Cluster  1660  :  1
# Cluster  1661  :  1
# Cluster  1662  :  1
# Cluster  1663  :  1
# Cluster  1664  :  1
# Cluster  1665  :  1
# Cluster  1666  :  3
# Cluster  1667  :  1
# Cluster  1668  :  1
# Cluster  1669  :  1
# Cluster  1670  :  1
# Cluster  1671  :  1
# Cluster  1672  :  1
# Cluster  1673  :  1
# Cluster  1674  :  1
# Cluster  1675  :  1
# Cluster  1676  :  1
# Cluster  1677  :  1
# Cluster  1678  :  1
# Cluster  1679  :  1
# Cluster  1680  :  1
# Cluster  1681  :  1
# Cluster  1682  :  2
# Cluster  1683  :  2
# Cluster  1684  :  1
# Cluster  1685  :  4
# Cluster  1686  :  1
# Cluster  1687  :  3
# Cluster  1688  :  2
# Cluster  1689  :  1
# Cluster  1690  :  2
# Cluster  1691  :  6
# Cluster  1692  :  3
# Cluster  1693  :  1
# Cluster  1694  :  5
# Cluster  1695  :  2
# Cluster  1696  :  1
# Cluster  1697  :  1
# Cluster  1698  :  2
# Cluster  1699  :  1
# Cluster  1700  :  1
# Cluster  1701  :  1
# Cluster  1702  :  1
# Cluster  1703  :  1
# Cluster  1704  :  1
# Cluster  1705  :  1
# Cluster  1706  :  1
# Cluster  1707  :  1
# Cluster  1708  :  1
# Cluster  1709  :  1
# Cluster  1710  :  1
# Cluster  1711  :  1
# Cluster  1712  :  1
# Cluster  1713  :  1
# Cluster  1714  :  1
# Cluster  1715  :  1
# Cluster  1716  :  1
# Cluster  1717  :  1
# Cluster  1718  :  1
# Cluster  1719  :  1
# Cluster  1720  :  1
# Cluster  1721  :  1
# Cluster  1722  :  1
# Cluster  1723  :  2
# Cluster  1724  :  2
# Cluster  1725  :  1
# Cluster  1726  :  1
# Cluster  1727  :  1
# Cluster  1728  :  1
# Cluster  1729  :  1
# Cluster  1730  :  1
# Cluster  1731  :  1
# Cluster  1732  :  3
# Cluster  1733  :  1
# Cluster  1734  :  1
# Cluster  1735  :  3
# Cluster  1736  :  1
# Cluster  1737  :  1
# Cluster  1738  :  1
# Cluster  1739  :  10
# Cluster  1740  :  1
# Cluster  1741  :  2
# Cluster  1742  :  1
# Cluster  1743  :  2
# Cluster  1744  :  1
# Cluster  1745  :  1
# Cluster  1746  :  1
# Cluster  1747  :  2
# Cluster  1748  :  1
# Cluster  1749  :  1
# Cluster  1750  :  1
# Cluster  1751  :  2
# Cluster  1752  :  1
# Cluster  1753  :  2
# Cluster  1754  :  1
# Cluster  1755  :  6
# Cluster  1756  :  6
# Cluster  1757  :  1
# Cluster  1758  :  2
# Cluster  1759  :  1
# Cluster  1760  :  1
# Cluster  1761  :  1
# Cluster  1762  :  1
# Cluster  1763  :  1
# Cluster  1764  :  1
# Cluster  1765  :  1
# Cluster  1766  :  1
# Cluster  1767  :  2
# Cluster  1768  :  1
# Cluster  1769  :  1
# Cluster  1770  :  1
# Cluster  1771  :  1
# Cluster  1772  :  4
# Cluster  1773  :  1
# Cluster  1774  :  1
# Cluster  1775  :  1
# Cluster  1776  :  1
# Cluster  1777  :  3
# Cluster  1778  :  1
# Cluster  1779  :  1
# Cluster  1780  :  1
# Cluster  1781  :  2
# Cluster  1782  :  1
# Cluster  1783  :  1
# Cluster  1784  :  2
# Cluster  1785  :  1
# Cluster  1786  :  3
# Cluster  1787  :  1
# Cluster  1788  :  2
# Cluster  1789  :  1
# Cluster  1790  :  1
# Cluster  1791  :  2
# Cluster  1792  :  2
# Cluster  1793  :  1
# Cluster  1794  :  3
# Cluster  1795  :  3
# Cluster  1796  :  3
# Cluster  1797  :  1
# Cluster  1798  :  1
# Cluster  1799  :  1
# Cluster  1800  :  1
# Cluster  1801  :  3
# Cluster  1802  :  1
# Cluster  1803  :  1
# Cluster  1804  :  1
# Cluster  1805  :  5
# Cluster  1806  :  1
# Cluster  1807  :  1
# Cluster  1808  :  1
# Cluster  1809  :  1
# Cluster  1810  :  1
# Cluster  1811  :  1
# Cluster  1812  :  1
# Cluster  1813  :  5
# Cluster  1814  :  1
# Cluster  1815  :  1
# Cluster  1816  :  2
# Cluster  1817  :  1
# Cluster  1818  :  1
# Cluster  1819  :  1
# Cluster  1820  :  1
# Cluster  1821  :  1
# Cluster  1822  :  1
# Cluster  1823  :  1
# Cluster  1824  :  1
# Cluster  1825  :  1
# Cluster  1826  :  1
# Cluster  1827  :  1
# Cluster  1828  :  1
# Cluster  1829  :  2
# Cluster  1830  :  1
# Cluster  1831  :  1
# Cluster  1832  :  1
# Cluster  1833  :  1
# Cluster  1834  :  2
# Cluster  1835  :  1
# Cluster  1836  :  1
# Cluster  1837  :  1
# Cluster  1838  :  3
# Cluster  1839  :  1
# Cluster  1840  :  1
# Cluster  1841  :  1
# Cluster  1842  :  1
# Cluster  1843  :  4
# Cluster  1844  :  1
# Cluster  1845  :  1
# Cluster  1846  :  1
# Cluster  1847  :  3
# Cluster  1848  :  1
# Cluster  1849  :  1
# Cluster  1850  :  1
# Cluster  1851  :  1
# Cluster  1852  :  1
# Cluster  1853  :  2
# Cluster  1854  :  1
# Cluster  1855  :  1
# Cluster  1856  :  1
# Cluster  1857  :  1
# Cluster  1858  :  1
# Cluster  1859  :  1
# Cluster  1860  :  1
# Cluster  1861  :  1
# Cluster  1862  :  1
# Cluster  1863  :  1
# Cluster  1864  :  1
# Cluster  1865  :  1
# Cluster  1866  :  1
# Cluster  1867  :  1
# Cluster  1868  :  1
# Cluster  1869  :  3
# Cluster  1870  :  1
# Cluster  1871  :  1
# Cluster  1872  :  1
# Cluster  1873  :  1
# Cluster  1874  :  1
# Cluster  1875  :  1
# Cluster  1876  :  1
# Cluster  1877  :  1
# Cluster  1878  :  1
# Cluster  1879  :  1
# Cluster  1880  :  2
# Cluster  1881  :  1
# Cluster  1882  :  1
# Cluster  1883  :  1
# Cluster  1884  :  1
# Cluster  1885  :  1
# Cluster  1886  :  1
# Cluster  1887  :  1
# Cluster  1888  :  1
# Cluster  1889  :  1
# Cluster  1890  :  1
# Cluster  1891  :  1
# Cluster  1892  :  2
# Cluster  1893  :  1
# Cluster  1894  :  1
# Cluster  1895  :  1
# Cluster  1896  :  1
# Cluster  1897  :  1
# Cluster  1898  :  1
# Cluster  1899  :  1
# Cluster  1900  :  1
# Cluster  1901  :  1
# Cluster  1902  :  1
# Cluster  1903  :  1
# Cluster  1904  :  2
# Cluster  1905  :  1
# Cluster  1906  :  2
# Cluster  1907  :  1
# Cluster  1908  :  1
# Cluster  1909  :  1
# Cluster  1910  :  2
# Cluster  1911  :  1
# Cluster  1912  :  1
# Cluster  1913  :  1
# Cluster  1914  :  1
# Cluster  1915  :  1
# Cluster  1916  :  1
# Cluster  1917  :  1
# Cluster  1918  :  1
# Cluster  1919  :  1
# Cluster  1920  :  1
# Cluster  1921  :  1
# Cluster  1922  :  3
# Cluster  1923  :  1
# Cluster  1924  :  1
# Cluster  1925  :  1
# Cluster  1926  :  1
# Cluster  1927  :  1
# Cluster  1928  :  1
# Cluster  1929  :  1
# Cluster  1930  :  1
# Cluster  1931  :  1
# Cluster  1932  :  1
# Cluster  1933  :  1
# Cluster  1934  :  2
# Cluster  1935  :  1
# Cluster  1936  :  2
# Cluster  1937  :  1
# Cluster  1938  :  2
# Cluster  1939  :  1
# Cluster  1940  :  1
# Cluster  1941  :  1
# Cluster  1942  :  3
# Cluster  1943  :  2
# Cluster  1944  :  1
# Cluster  1945  :  1
# Cluster  1946  :  1
# Cluster  1947  :  1
# Cluster  1948  :  1
# Cluster  1949  :  1
# Cluster  1950  :  1
# Cluster  1951  :  1
# Cluster  1952  :  1
# Cluster  1953  :  1
# Cluster  1954  :  1
# Cluster  1955  :  4
# Cluster  1956  :  1
# Cluster  1957  :  1
# Cluster  1958  :  3
# Cluster  1959  :  1
# Cluster  1960  :  1
# Cluster  1961  :  1
# Cluster  1962  :  1
# Cluster  1963  :  1
# Cluster  1964  :  1
# Cluster  1965  :  2
# Cluster  1966  :  3
# Cluster  1967  :  1
# Cluster  1968  :  1
# Cluster  1969  :  1
# Cluster  1970  :  1
# Cluster  1971  :  2
# Cluster  1972  :  4
# Cluster  1973  :  1
# Cluster  1974  :  1
# Cluster  1975  :  1
# Cluster  1976  :  1
# Cluster  1977  :  1
# Cluster  1978  :  1
# Cluster  1979  :  1
# Cluster  1980  :  1
# Cluster  1981  :  1
# Cluster  1982  :  1
# Cluster  1983  :  1
# Cluster  1984  :  1
# Cluster  1985  :  1
# Cluster  1986  :  1
# Cluster  1987  :  1
# Cluster  1988  :  1
# Cluster  2697  :  1
# Cluster  2698  :  1
# Cluster  2699  :  1
# Cluster  2700  :  1
# Cluster  2701  :  1
# Cluster  2702  :  1
# Cluster  2703  :  1
# Cluster  2704  :  1
# Cluster  2705  :  1
# Cluster  2706  :  1
# Cluster  2707  :  1
# Cluster  2708  :  1
# Cluster  2709  :  1
# Cluster  2710  :  1
# Cluster  2711  :  1
# Cluster  2712  :  1
# Cluster  2713  :  1
# Cluster  2714  :  1
# Cluster  2715  :  1
# Cluster  2716  :  1
# Cluster  2717  :  1
# Cluster  2718  :  1
# Cluster  2719  :  1
# Cluster  2720  :  1
# Cluster  2721  :  1
# Cluster  2722  :  1
# Cluster  2723  :  1
# Cluster  2724  :  1
# Cluster  2725  :  1
# Cluster  2726  :  1
# Cluster  2727  :  1
# Cluster  2728  :  1
# Cluster  2729  :  1
# Cluster  2730  :  5
# Cluster  2731  :  1
# Cluster  2732  :  1
# Cluster  2733  :  2
# Cluster  2734  :  3
# Cluster  2735  :  2
# Cluster  2736  :  1
# Cluster  2737  :  1
# Cluster  2738  :  1
# Cluster  2739  :  2
# Cluster  2740  :  1
# Cluster  2741  :  1
# Cluster  2742  :  1
# Cluster  2743  :  1
# Cluster  2744  :  1
# Cluster  2745  :  1
# Cluster  2746  :  1
# Total number of vectors:  3517

# %%
# plot graph to show cluster index vs cluster size of covid clusters

for i in range(0, len(updated_covid_clusters)):
    plt.scatter(i, len(updated_covid_clusters[i]), color='red')

plt.title('Covid Clusters')
plt.xlabel('Cluster Index')
plt.ylabel('Cluster Size')
plt.show()

# %% [markdown]
# ` Reclustering pneumonia vectors `

# %%
r = 1600

updated_pneumonia_clusters = []  # list of clusters

updated_cluster=[]
check = []
for i in range(0, len(updated_pneumonia_vectors)-1):
    updated_cluster = []
    if updated_pneumonia_vectors[i] not in check:
        updated_cluster.append(updated_pneumonia_vectors[i])
        check.append(updated_pneumonia_vectors[i])
    else:
        continue
    for j in range(i+1, len(updated_pneumonia_vectors)):

        if euclidean_distance(updated_pneumonia_vectors[i], updated_pneumonia_vectors[j]) <= r:
            if updated_pneumonia_vectors[j] not in check:
                updated_cluster.append(updated_pneumonia_vectors[j])
                check.append(updated_pneumonia_vectors[j])

    updated_pneumonia_clusters.append(updated_cluster)

# %%
# print the clusters
sum=0
for i in range(0, len(updated_pneumonia_clusters)):
    print("Cluster ", i+1, " : ", len(updated_pneumonia_clusters[i]))
    sum+=len(updated_pneumonia_clusters[i])
print("Total number of vectors: ", sum)
# Out:
# Cluster  1  :  22
# Cluster  2  :  26
# Cluster  3  :  41
# Cluster  4  :  26
# Cluster  5  :  25
# Cluster  6  :  5
# Cluster  7  :  13
# Cluster  8  :  11
# Cluster  9  :  16
# Cluster  10  :  3
# Cluster  11  :  1
# Cluster  12  :  2
# Cluster  13  :  3
# Cluster  14  :  5
# Cluster  15  :  3
# Cluster  16  :  4
# Cluster  17  :  6
# Cluster  18  :  28
# Cluster  19  :  13
# Cluster  20  :  1
# Cluster  21  :  1
# Cluster  22  :  1
# Cluster  23  :  13
# Cluster  24  :  5
# Cluster  25  :  7
# Cluster  26  :  4
# Cluster  27  :  1
# Cluster  28  :  6
# Cluster  29  :  1
# Cluster  30  :  5
# Cluster  31  :  2
# Cluster  32  :  4
# Cluster  33  :  1
# Cluster  34  :  1
# Cluster  35  :  1
# Cluster  36  :  7
# Cluster  37  :  1
# Cluster  38  :  1
# Cluster  39  :  1
# Cluster  40  :  1
# Cluster  41  :  1
# Cluster  42  :  4
# Cluster  43  :  8
# Cluster  44  :  7
# Cluster  45  :  1
# Cluster  46  :  24
# Cluster  47  :  19
# Cluster  48  :  13
# Cluster  49  :  8
# Cluster  50  :  1
# Cluster  51  :  1
# Cluster  52  :  1
# Cluster  53  :  2
# Cluster  54  :  1
# Cluster  55  :  1
# Cluster  56  :  1
# Cluster  57  :  13
# Cluster  58  :  4
# Cluster  59  :  5
# Cluster  60  :  3
# Cluster  61  :  1
# Cluster  62  :  8
# Cluster  63  :  33
# Cluster  64  :  11
# Cluster  65  :  15
# Cluster  66  :  1
# Cluster  67  :  13
# Cluster  68  :  9
# Cluster  69  :  23
# Cluster  70  :  4
# Cluster  71  :  1
# Cluster  72  :  2
# Cluster  73  :  15
# Cluster  74  :  1
# Cluster  75  :  2
# Cluster  76  :  9
# Cluster  77  :  9
# Cluster  78  :  10
# Cluster  79  :  2
# Cluster  80  :  1
# Cluster  81  :  12
# Cluster  82  :  3
# Cluster  83  :  1
# Cluster  84  :  4
# Cluster  85  :  1
# Cluster  86  :  9
# Cluster  87  :  2
# Cluster  88  :  1
# Cluster  89  :  5
# Cluster  90  :  9
# Cluster  91  :  3
# Cluster  92  :  1
# Cluster  93  :  3
# Cluster  94  :  1
# Cluster  95  :  5
# Cluster  96  :  1
# Cluster  97  :  1
# Cluster  98  :  3
# Cluster  99  :  1
# Cluster  100  :  10
# Cluster  101  :  1
# Cluster  102  :  8
# Cluster  103  :  5
# Cluster  104  :  1
# Cluster  105  :  1
# Cluster  106  :  4
# Cluster  107  :  1
# Cluster  108  :  3
# Cluster  109  :  4
# Cluster  110  :  1
# Cluster  111  :  4
# Cluster  112  :  2
# Cluster  113  :  1
# Cluster  114  :  3
# Cluster  115  :  1
# Cluster  116  :  1
# Cluster  117  :  1
# Cluster  118  :  3
# Cluster  119  :  2
# Cluster  120  :  1
# Cluster  121  :  1
# Cluster  122  :  1
# Cluster  123  :  1
# Cluster  124  :  5
# Cluster  125  :  1
# Cluster  126  :  1
# Cluster  127  :  1
# Cluster  128  :  2
# Cluster  129  :  3
# Cluster  130  :  1
# Cluster  131  :  9
# Cluster  132  :  3
# Cluster  133  :  1
# Cluster  134  :  1
# Cluster  135  :  4
# Cluster  136  :  1
# Cluster  137  :  1
# Cluster  138  :  1
# Cluster  139  :  1
# Cluster  140  :  1
# Cluster  141  :  1
# Cluster  142  :  8
# Cluster  143  :  1
# Cluster  144  :  3
# Cluster  145  :  1
# Cluster  146  :  2
# Cluster  147  :  2
# Cluster  148  :  1
# Cluster  149  :  1
# Cluster  150  :  1
# Cluster  151  :  1
# Cluster  152  :  1
# Cluster  153  :  1
# Cluster  154  :  2
# Cluster  410  :  1
# Cluster  411  :  2
# Cluster  412  :  1
# Cluster  413  :  1
# Cluster  414  :  1
# Cluster  415  :  1
# Cluster  416  :  1
# Cluster  417  :  1
# Cluster  418  :  1
# Cluster  419  :  2
# Cluster  420  :  1
# Cluster  421  :  1
# Cluster  422  :  1
# Cluster  423  :  1
# Cluster  424  :  1
# Cluster  425  :  1
# Cluster  426  :  1
# Cluster  427  :  1
# Cluster  428  :  1
# Cluster  429  :  1
# Cluster  430  :  1
# Cluster  431  :  1
# Cluster  432  :  1
# Cluster  433  :  1
# Cluster  434  :  1
# Cluster  435  :  1
# Cluster  436  :  1
# Cluster  437  :  2
# Cluster  438  :  1
# Cluster  439  :  1
# Cluster  440  :  1
# Cluster  441  :  1
# Cluster  442  :  1
# Cluster  443  :  1
# Cluster  444  :  1
# Cluster  445  :  1
# Cluster  446  :  1
# Cluster  447  :  1
# Cluster  448  :  1
# Cluster  449  :  1
# Cluster  450  :  1
# Cluster  451  :  1
# Cluster  452  :  1
# Cluster  453  :  1
# Cluster  454  :  1
# Cluster  455  :  1
# Cluster  456  :  1
# Cluster  457  :  1
# Cluster  458  :  1
# Cluster  459  :  1
# Cluster  460  :  1
# Cluster  461  :  1
# Cluster  462  :  1
# Cluster  463  :  1
# Cluster  464  :  1
# Cluster  465  :  1
# Cluster  466  :  1
# Cluster  467  :  1
# Cluster  468  :  1
# Cluster  469  :  1
# Cluster  470  :  1
# Cluster  471  :  2
# Cluster  472  :  1
# Cluster  473  :  1
# Cluster  474  :  1
# Cluster  475  :  1
# Cluster  476  :  1
# Cluster  477  :  1
# Cluster  478  :  1
# Cluster  479  :  4
# Cluster  480  :  5
# Cluster  481  :  2
# Cluster  482  :  3
# Cluster  483  :  3
# Cluster  484  :  2
# Cluster  485  :  5
# Cluster  486  :  3
# Cluster  487  :  2
# Cluster  488  :  1
# Cluster  489  :  1
# Cluster  490  :  1
# Cluster  491  :  1
# Cluster  492  :  1
# Cluster  493  :  2
# Cluster  494  :  2
# Cluster  495  :  1
# Cluster  496  :  1
# Cluster  497  :  1
# Cluster  498  :  1
# Cluster  499  :  1
# Cluster  500  :  1
# Total number of vectors:  1333

# %%
# plot graph to show cluster index vs cluster size of pneumonia clusters

for i in range(0, len(updated_pneumonia_clusters)):
    plt.scatter(i, len(updated_pneumonia_clusters[i]), color='blue')

plt.title('Pneumonia Clusters')
plt.xlabel('Cluster Index')
plt.ylabel('Cluster Size')
plt.show()

# %% [markdown]
# ### Averaging the clusters
#
#     - Average the vectors in each sub-cluster to get the prototype vector for each cluster
#     - Each average vector will represent the prototype vector for each class

# %% [markdown]
# ` Normal Prototype Vectors `

# %%
# get the average of each sub-cluster in updated_normal_clusters
normal_prototypes = []
for i in range(0, len(updated_normal_clusters)):
    normal_prototypes.append(np.mean(updated_normal_clusters[i], axis=0))

# print the normal_prototypes
print("No. of Normal prototypes: ", len(normal_prototypes))
# Out:
# No. of Normal prototypes:  5210

# %%
# plot the projection of normal_prototypes in 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(0, len(normal_prototypes)):
    ax.scatter(normal_prototypes[i][0], normal_prototypes[i][1], normal_prototypes[i][2], color='green')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# ` Covid Prototype Vectors `

# %%
# get the average of each sub-cluster in updated_covid_clusters
covid_prototypes = []
for i in range(0, len(updated_covid_clusters)):
    covid_prototypes.append(np.mean(updated_covid_clusters[i], axis=0))

# print the covid_prototypes
print("No. of Covid prototypes: ", len(covid_prototypes))
# Out:
# No. of Covid prototypes:  2746

# %%
# plot the projection of covid_prototypes in 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(0, len(covid_prototypes)):
    ax.scatter(covid_prototypes[i][0], covid_prototypes[i][1], covid_prototypes[i][2], color='red') 

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# ` Pneumonia Prototype Vectors `

# %%
# get the average of each sub-cluster in updated_pneumonia_clusters
pneumonia_prototypes = []
for i in range(0, len(updated_pneumonia_clusters)):
    pneumonia_prototypes.append(np.mean(updated_pneumonia_clusters[i], axis=0))

# print the pneumonia_prototypes
print("No. of Pneumonia prototypes: ", len(pneumonia_prototypes))
# Out:
# No. of Pneumonia prototypes:  500

# %%
# plot the projection of pneumonia_prototypes in 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(0, len(pneumonia_prototypes)):
    ax.scatter(pneumonia_prototypes[i][0], pneumonia_prototypes[i][1], pneumonia_prototypes[i][2], color='blue')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# ` All Prototype Vectors in 1 graph `

# %%
# plot the projection of normal_prototypes, covid_prototypes and pneumonia_prototypes in 2D space

for i in range(0, len(normal_prototypes)):
    plt.scatter(normal_prototypes[i][0], normal_prototypes[i][1], color='green')

for i in range(0, len(covid_prototypes)):
    plt.scatter(covid_prototypes[i][0], covid_prototypes[i][1], color='red')

for i in range(0, len(pneumonia_prototypes)):
    plt.scatter(pneumonia_prototypes[i][0], pneumonia_prototypes[i][1], color='blue')

plt.title('Normal, Covid and Pneumonia Prototypes')
plt.xlabel('X Label')
plt.ylabel('Y Label')
# show legend for the plot with labels and colors   
green_patch = mpatches.Patch(color='green', label='Normal')
red_patch = mpatches.Patch(color='red', label='Covid')
blue_patch = mpatches.Patch(color='blue', label='Pneumonia')
plt.legend(handles=[green_patch, red_patch, blue_patch])


plt.show()

# %%
# plot the projection of normal_prototypes, covid_prototypes and pneumonia_prototypes in 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(0, len(normal_prototypes)):
    ax.scatter(normal_prototypes[i][0], normal_prototypes[i][1], normal_prototypes[i][2], color='green')

for i in range(0, len(covid_prototypes)):
    ax.scatter(covid_prototypes[i][0], covid_prototypes[i][1], covid_prototypes[i][2], color='red')

for i in range(0, len(pneumonia_prototypes)):
    ax.scatter(pneumonia_prototypes[i][0], pneumonia_prototypes[i][1], pneumonia_prototypes[i][2], color='blue')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# show legend for the plot with labels and colors   
green_patch = mpatches.Patch(color='green', label='Normal')
red_patch = mpatches.Patch(color='red', label='Covid')
blue_patch = mpatches.Patch(color='blue', label='Pneumonia')
plt.legend(handles=[green_patch, red_patch, blue_patch])

plt.show()

# %% [markdown]
# ### Load the Test Images
#
#     ` Normal Lungs Test Images `
#
#     ` Pneumonia Lungs Test Images `
#
#     ` COVID Lungs Test Images

# %%
covid_test_images_length = len(os.listdir(
    './COVID-19_Radiography_Dataset/COVID/test_images_sharpen/'))
normal_test_images_length = len(os.listdir(
    './COVID-19_Radiography_Dataset/Normal/test_images_sharpen/'))
pneumonia_test_images_length = len(os.listdir(
    './COVID-19_Radiography_Dataset/Viral Pneumonia/test_images_sharpen/'))

print("No. of Covid test images: ", covid_test_images_length)

print("No. of Normal test images: ", normal_test_images_length)

print("No. of Pneumonia test images: ", pneumonia_test_images_length)
# get the test images
covid_test_images = []
normal_test_images = []
pneumonia_test_images = []

for i in range(1, normal_images_length+1):
    normal_test_images.append(cv2.imread(
        './COVID-19_Radiography_Dataset/Normal/test_images_sharpen/Normal-'+str(i)+'.png'))

for i in range(1, covid_test_images_length+1):
    covid_test_images.append(cv2.imread(
        './COVID-19_Radiography_Dataset/COVID/test_images_sharpen/COVID-'+str(i)+'.png'))

for i in range(1, pneumonia_test_images_length+1):
    pneumonia_test_images.append(cv2.imread(
        './COVID-19_Radiography_Dataset/Viral Pneumonia/test_images_sharpen/Viral Pneumonia-'+str(i)+'.png'))
# Out:
# No. of Covid test images:  205
# No. of Normal test images:  205
# No. of Pneumonia test images:  205

# %%
#! Display image no. 10 to image no. 15 from each class with labels with numbers in same plot
fig, axs = plt.subplots(3, 5, figsize=(15, 15))
fig.suptitle('Covid, Normal and Pneumonia Test Images')

for i in range(0, 5):
    axs[0, i].imshow(covid_test_images[i+5])
    axs[0, i].set_title('Covid-'+str(i+1))
    axs[1, i].imshow(normal_test_images[i+5])
    axs[1, i].set_title('Normal-'+str(i+1))
    axs[2, i].imshow(pneumonia_test_images[i+5])
    axs[2, i].set_title('Pneumonia-'+str(i+1))

plt.show()

# %% [markdown]
# ### Load the Test Vectors
#
#     ` Normal Lungs Test Vector `
#
#     ` Pneumonia Lungs Test Vector `
#
#     ` COVID Lungs Test Vector `

# %%
# get the test vectors
covid_test_vectors = loadFile('./COVID-19_Radiography_Dataset/COVID/covid_test_vector.txt')
normal_test_vectors = loadFile('./COVID-19_Radiography_Dataset/Normal/normal_test_vector.txt')
pneumonia_test_vectors = loadFile('./COVID-19_Radiography_Dataset/Viral Pneumonia/pneumonia_test_vector.txt')

# print test vectors
print("No. of Covid test vectors: ", len(covid_test_vectors))
print("No. of Normal test vectors: ", len(normal_test_vectors))
print("No. of Pneumonia test vectors: ", len(pneumonia_test_vectors))
# Out:
# No. of Covid test vectors:  205
# No. of Normal test vectors:  205
# No. of Pneumonia test vectors:  205

# %%
# plot the projection of normal_test_vectors, covid_test_vectors and pneumonia_test_vectors in 2D space

for i in range(0, len(normal_test_vectors)):
    plt.scatter(normal_test_vectors[i][0], normal_test_vectors[i][1], color='green')

for i in range(0, len(covid_test_vectors)):
    plt.scatter(covid_test_vectors[i][0], covid_test_vectors[i][1], color='red')

for i in range(0, len(pneumonia_test_vectors)):
    plt.scatter(pneumonia_test_vectors[i][0], pneumonia_test_vectors[i][1], color='blue')

plt.xlabel('X Label')
plt.ylabel('Y Label')

# show legend for the plot with labels and colors
green_patch = mpatches.Patch(color='green', label='Normal Test Vectors')
red_patch = mpatches.Patch(color='red', label='Covid Test Vectors')
blue_patch = mpatches.Patch(color='blue', label='Pneumonia Test Vectors')
plt.legend(handles=[green_patch, red_patch, blue_patch])

plt.show()

# %%
# plot the projection of normal_test_vectors, covid_test_vectors and pneumonia_test_vectors in 3D space

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(0, len(normal_test_vectors)):
    ax.scatter(normal_test_vectors[i][0], normal_test_vectors[i][1], normal_test_vectors[i][2], color='green')

for i in range(0, len(covid_test_vectors)):
    ax.scatter(covid_test_vectors[i][0], covid_test_vectors[i][1], covid_test_vectors[i][2], color='red')

for i in range(0, len(pneumonia_test_vectors)):
    ax.scatter(pneumonia_test_vectors[i][0], pneumonia_test_vectors[i][1], pneumonia_test_vectors[i][2], color='blue')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# show legend for the plot with labels and colors
green_patch = mpatches.Patch(color='green', label='Normal Test Vectors')
red_patch = mpatches.Patch(color='red', label='Covid Test Vectors')
blue_patch = mpatches.Patch(color='blue', label='Pneumonia Test Vectors')
plt.legend(handles=[green_patch, red_patch, blue_patch])

plt.show()

# %% [markdown]
# ### Get Distance of Test Vectors from Prototype Vectors

# %% [markdown]
# 1. For Covid Test Image

# %% [markdown]
# ` Considering the first test vector from covid_test_vector`
#
#     - Get the distance of the test vector from each prototype vector of each class
#     - Get the minimum distance and the index of the prototype vector from which the minimum distance is obtained of each class

# %%
test_vector = covid_test_vectors[0]
test_image = covid_test_images[0]

covid_prototype_index, covid_prototype_distance = getPrototype(test_vector, covid_prototypes)
normal_prototype_index, normal_prototype_distance = getPrototype(test_vector, normal_prototypes)
pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(test_vector, pneumonia_prototypes)

print("\n Class Covid =>","\tPrototype Index: ", covid_prototype_index, "\tPrototype Distance: ", covid_prototype_distance)

print("\n Class Normal =>","\tPrototype Index: ", normal_prototype_index, "\tPrototype Distance: ", normal_prototype_distance)

print("\n Class Pneumonia =>","\tPrototype Index: ", pneumonia_prototype_index, "\tPrototype Distance: ", pneumonia_prototype_distance)
# Out:
#  Class Covid => 	Prototype Index:  0 	Prototype Distance:  423.8802897045344
#
#  Class Normal => 	Prototype Index:  3497 	Prototype Distance:  2433.0774751330873
#
#  Class Pneumonia => 	Prototype Index:  157 	Prototype Distance:  2627.2531282691434

# %% [markdown]
# ` Compare the minimum distance of each class and get the membership value of the test vector for each class`

# %%
# get membership values for each class
covid_membership = getDegreeOfMembership("covid",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
normal_membership = getDegreeOfMembership("normal",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
pneumonia_membership = getDegreeOfMembership("pneumonia",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)

print("\n Class Covid =>","\tDegree of Membership: ", covid_membership)

print("\n Class Normal =>","\tDegree of Membership: ", normal_membership)

print("\n Class Pneumonia =>","\tDegree of Membership: ", pneumonia_membership)

print("\n\n The  %  of input image being Covid is: ", covid_membership*100,"%")

print("\n The  %  of input image being Normal is: ", normal_membership*100,"%")

print("\n The  %  of input image being Pneumonia is: ", pneumonia_membership*100,"%")
# Out:
#  Class Covid => 	Degree of Membership:  0.9227089734573629
#
#  Class Normal => 	Degree of Membership:  0.5563486666438593
#
#  Class Pneumonia => 	Degree of Membership:  0.5209423598987777
#
#
#  The  %  of input image being Covid is:  92.27089734573629 %
#
#  The  %  of input image being Normal is:  55.63486666438593 %
#
#  The  %  of input image being Pneumonia is:  52.09423598987777 %

# %% [markdown]
# ### Assign Class
#     - Assign the class with maximum membership value

# %%
# assign class

assigned_class = assignClass(covid_membership, normal_membership, pneumonia_membership)

print("\n\n The assigned class is: ", assigned_class)

# plot the test image
plt.imshow(test_image)
plt.title('Test Image')
plt.show()
# Out:
#  The assigned class is:  covid

# %% [markdown]
# 2. For Normal Test Image

# %% [markdown]
# ` Considering any vector from normal_test_vector`
#
#     - Get the distance of the test vector from each prototype vector of each class
#     - Get the minimum distance and the index of the prototype vector from which the minimum distance is obtained of each class

# %%
test_vector = normal_test_vectors[5]
test_image = normal_test_images[5]

covid_prototype_index, covid_prototype_distance = getPrototype(test_vector, covid_prototypes)
normal_prototype_index, normal_prototype_distance = getPrototype(test_vector, normal_prototypes)
pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(test_vector, pneumonia_prototypes)

print("\n Class Covid =>","\tPrototype Index: ", covid_prototype_index, "\tPrototype Distance: ", covid_prototype_distance)

print("\n Class Normal =>","\tPrototype Index: ", normal_prototype_index, "\tPrototype Distance: ", normal_prototype_distance)

print("\n Class Pneumonia =>","\tPrototype Index: ", pneumonia_prototype_index, "\tPrototype Distance: ", pneumonia_prototype_distance)
# Out:
#  Class Covid => 	Prototype Index:  165 	Prototype Distance:  1611.5241233068775
#
#  Class Normal => 	Prototype Index:  82 	Prototype Distance:  537.5917834378
#
#  Class Pneumonia => 	Prototype Index:  126 	Prototype Distance:  2132.1904230157306

# %% [markdown]
# ` Compare the minimum distance of each class and get the membership value of the test vector for each class`

# %%
# get membership values for each class
covid_membership = getDegreeOfMembership("covid",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
normal_membership = getDegreeOfMembership("normal",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
pneumonia_membership = getDegreeOfMembership("pneumonia",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)

print("\n Class Covid =>","\tDegree of Membership: ", covid_membership)

print("\n Class Normal =>","\tDegree of Membership: ", normal_membership)

print("\n Class Pneumonia =>","\tDegree of Membership: ", pneumonia_membership)

print("\n\n The  %  of input image being Covid is: ", covid_membership*100,"%")

print("\n The  %  of input image being Normal is: ", normal_membership*100,"%")

print("\n The  %  of input image being Pneumonia is: ", pneumonia_membership*100,"%")
# Out:
#  Class Covid => 	Degree of Membership:  0.6235905587729663
#
#  Class Normal => 	Degree of Membership:  0.8744327684050851
#
#  Class Pneumonia => 	Degree of Membership:  0.5019766728219485
#
#
#  The  %  of input image being Covid is:  62.35905587729663 %
#
#  The  %  of input image being Normal is:  87.44327684050852 %
#
#  The  %  of input image being Pneumonia is:  50.19766728219485 %

# %% [markdown]
# ### Assign Class
#     - Assign the class with maximum membership value

# %%
# assign class

assigned_class = assignClass(covid_membership, normal_membership, pneumonia_membership)

print("\n\n The assigned class is: ", assigned_class)

# plot the test image
plt.imshow(test_image)
plt.title('Test Image')
plt.show()
# Out:
#  The assigned class is:  normal

# %% [markdown]
# 3. For Pneumonia Test Image

# %% [markdown]
# ` Considering any vector from pneumonia_test_vector`
#
#     - Get the distance of the test vector from each prototype vector of each class
#     - Get the minimum distance and the index of the prototype vector from which the minimum distance is obtained of each class

# %%
test_vector = pneumonia_test_vectors[5]
test_image = pneumonia_test_images[5]

covid_prototype_index, covid_prototype_distance = getPrototype(test_vector, covid_prototypes)
normal_prototype_index, normal_prototype_distance = getPrototype(test_vector, normal_prototypes)
pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(test_vector, pneumonia_prototypes)

print("\n Class Covid =>","\tPrototype Index: ", covid_prototype_index, "\tPrototype Distance: ", covid_prototype_distance)

print("\n Class Normal =>","\tPrototype Index: ", normal_prototype_index, "\tPrototype Distance: ", normal_prototype_distance)

print("\n Class Pneumonia =>","\tPrototype Index: ", pneumonia_prototype_index, "\tPrototype Distance: ", pneumonia_prototype_distance)
# Out:
#  Class Covid => 	Prototype Index:  1945 	Prototype Distance:  1657.1318595694188
#
#  Class Normal => 	Prototype Index:  4913 	Prototype Distance:  1099.1796941355858
#
#  Class Pneumonia => 	Prototype Index:  4 	Prototype Distance:  738.2252100815848

# %% [markdown]
# ` Compare the minimum distance of each class and get the membership value of the test vector for each class`

# %%
# get membership values for each class
covid_membership = getDegreeOfMembership("covid",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
normal_membership = getDegreeOfMembership("normal",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
pneumonia_membership = getDegreeOfMembership("pneumonia",covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)

print("\n Class Covid =>","\tDegree of Membership: ", covid_membership)

print("\n Class Normal =>","\tDegree of Membership: ", normal_membership)

print("\n Class Pneumonia =>","\tDegree of Membership: ", pneumonia_membership)

print("\n\n The  %  of input image being Covid is: ", covid_membership*100,"%")

print("\n The  %  of input image being Normal is: ", normal_membership*100,"%")

print("\n The  %  of input image being Pneumonia is: ", pneumonia_membership*100,"%")
# Out:
#  Class Covid => 	Degree of Membership:  0.5257935538861541
#
#  Class Normal => 	Degree of Membership:  0.685457681966252
#
#  Class Pneumonia => 	Degree of Membership:  0.7887487641475939
#
#
#  The  %  of input image being Covid is:  52.57935538861541 %
#
#  The  %  of input image being Normal is:  68.5457681966252 %
#
#  The  %  of input image being Pneumonia is:  78.87487641475938 %

# %% [markdown]
# ### Assign Class
#     - Assign the class with maximum membership value

# %%
# assign class

assigned_class = assignClass(covid_membership, normal_membership, pneumonia_membership)

print("\n\n The assigned class is: ", assigned_class)

# plot the test image
plt.imshow(test_image)
plt.title('Test Image')
plt.show()
# Out:
#  The assigned class is:  normal

# %% [markdown]
# 4. For all test images

# %%
covidCorrectlyClassified = 0
normalCorrectlyClassified = 0
pneumoniaCorrectlyClassified = 0

#! for covid test vectors
for i in range(0, len(covid_test_vectors)):
    #!get the distances of each test vector with each prototype of each class
    covid_prototype_index, covid_prototype_distance = getPrototype(
        covid_test_vectors[i], covid_prototypes)
    normal_prototype_index, normal_prototype_distance = getPrototype(
        covid_test_vectors[i], normal_prototypes)
    pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(
        covid_test_vectors[i], pneumonia_prototypes)
    #! get the membership of each test vector for each class
    covid_membership = getDegreeOfMembership(
        "covid", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    normal_membership = getDegreeOfMembership(
        "normal", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    pneumonia_membership = getDegreeOfMembership(
        "pneumonia", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    #! assign class to each test vector
    assigned_class = assignClass(
        covid_membership, normal_membership, pneumonia_membership)
    #! if "covid" is assigned then increment the counter
    if assigned_class == "covid":
        covidCorrectlyClassified = covidCorrectlyClassified + 1

#! for normal test vectors
for i in range(0, len(normal_test_vectors)):
    #!get the distances of each test vector with each prototype of each class
    covid_prototype_index, covid_prototype_distance = getPrototype(
        normal_test_vectors[i], covid_prototypes)
    normal_prototype_index, normal_prototype_distance = getPrototype(
        normal_test_vectors[i], normal_prototypes)
    pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(
        normal_test_vectors[i], pneumonia_prototypes)
    #! get the membership of each test vector for each class
    covid_membership = getDegreeOfMembership(
        "covid", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    normal_membership = getDegreeOfMembership(
        "normal", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    pneumonia_membership = getDegreeOfMembership(
        "pneumonia", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    #! assign class to each test vector
    assigned_class = assignClass(
        covid_membership, normal_membership, pneumonia_membership)
    #! if "covid" is assigned then increment the counter
    if assigned_class == "normal":
        normalCorrectlyClassified = normalCorrectlyClassified + 1

#! for pneumonia test vectors
for i in range(0, len(pneumonia_test_vectors)):
    #!get the distances of each test vector with each prototype of each class
    covid_prototype_index, covid_prototype_distance = getPrototype(
        pneumonia_test_vectors[i], covid_prototypes)
    normal_prototype_index, normal_prototype_distance = getPrototype(
        pneumonia_test_vectors[i], normal_prototypes)
    pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(
        pneumonia_test_vectors[i], pneumonia_prototypes)
    #! get the membership of each test vector for each class
    covid_membership = getDegreeOfMembership(
        "covid", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    normal_membership = getDegreeOfMembership(
        "normal", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    pneumonia_membership = getDegreeOfMembership(
        "pneumonia", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    #! assign class to each test vector
    assigned_class = assignClass(
        covid_membership, normal_membership, pneumonia_membership)
    #! if "covid" is assigned then increment the counter
    if assigned_class == "pneumonia":
        pneumoniaCorrectlyClassified = pneumoniaCorrectlyClassified + 1

# %%
totalTestImages = len(pneumonia_test_vectors) + len(covid_test_vectors) + len(normal_test_vectors)
correctlyClassifiedImages = pneumoniaCorrectlyClassified + covidCorrectlyClassified + normalCorrectlyClassified

accuracyOfModel = accuracy(totalTestImages, correctlyClassifiedImages)

print("Covid correctly classified:\t", covidCorrectlyClassified)
print("Normal correctly classified:\t", normalCorrectlyClassified)
print("Pneumonia correctly classified\t: ", pneumoniaCorrectlyClassified)

print("\n\nAccuracy=>\t", accuracyOfModel)
# Out:
# Covid correctly classified:	 204
# Normal correctly classified:	 205
# Pneumonia correctly classified	:  86
#
#
# Accuracy=>	 80.48780487804879

# %%
# plot the above results
plt.bar(['Covid', 'Normal', 'Pneumonia'], [covidCorrectlyClassified, normalCorrectlyClassified, pneumoniaCorrectlyClassified])
plt.title('Correctly Classified Images')
plt.show()

# %% [markdown]
# ### Testing for a random image which may or may not have lungs xray

# %% [markdown]
# 1. Contains Covid infected lungs

# %%
test_image  = cv2.imread('./covid_test.png')
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# plot the test image
plt.imshow(test_image, cmap='gray')
plt.title('Covid Test Image')
plt.show()

if not is_lung_image(test_image):
    print("The image does not contain lungs")
else:
    test_vector = get_img_vector(test_image)

    # get the distances of each test vector with each prototype of each class
    covid_prototype_index, covid_prototype_distance = getPrototype(test_vector, covid_prototypes)
    normal_prototype_index, normal_prototype_distance = getPrototype(test_vector, normal_prototypes)
    pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(test_vector, pneumonia_prototypes)

    print("\n Class Covid =>","\tPrototype Index: ", covid_prototype_index, "\tPrototype Distance: ", covid_prototype_distance)

    print("\n Class Normal =>","\tPrototype Index: ", normal_prototype_index, "\tPrototype Distance: ", normal_prototype_distance)

    print("\n Class Pneumonia =>","\tPrototype Index: ", pneumonia_prototype_index, "\tPrototype Distance: ", pneumonia_prototype_distance)

    # get the membership of each test vector for each class
    covid_membership = getDegreeOfMembership("covid", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    normal_membership = getDegreeOfMembership("normal", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    pneumonia_membership = getDegreeOfMembership("pneumonia", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)

    print("\n Class Covid =>","\tMembership: ", covid_membership)

    print("\n Class Normal =>","\tMembership: ", normal_membership)

    print("\n Class Pneumonia =>","\tMembership: ", pneumonia_membership)

    # assign class to each test vector
    assigned_class = assignClass(covid_membership, normal_membership, pneumonia_membership)

    print("\n Assigned Class =>", assigned_class)
# Out:
#  Class Covid => 	Prototype Index:  614 	Prototype Distance:  33532.34016587569
#
#  Class Normal => 	Prototype Index:  1355 	Prototype Distance:  33579.38937800984
#
#  Class Pneumonia => 	Prototype Index:  452 	Prototype Distance:  34974.19535886423
#
#  Class Covid => 	Membership:  0.6715282719158431
#
#  Class Normal => 	Membership:  0.6710673933747615
#
#  Class Pneumonia => 	Membership:  0.6574043347093956
#
#  Assigned Class => covid

# %% [markdown]
# 2. Contains normal lungs

# %%
test_image  = cv2.imread('./normal_test_2.png')
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# plot the test image 
plt.imshow(test_image, cmap='gray')
plt.title('Normal Test Image')
plt.show()

if not is_lung_image(test_image):
    print("The image does not contain lungs")
else:
    test_vector = get_img_vector(test_image)

    # get the distances of each test vector with each prototype of each class
    covid_prototype_index, covid_prototype_distance = getPrototype(test_vector, covid_prototypes)
    normal_prototype_index, normal_prototype_distance = getPrototype(test_vector, normal_prototypes)
    pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(test_vector, pneumonia_prototypes)

    print("\n Class Covid =>","\tPrototype Index: ", covid_prototype_index, "\tPrototype Distance: ", covid_prototype_distance)

    print("\n Class Normal =>","\tPrototype Index: ", normal_prototype_index, "\tPrototype Distance: ", normal_prototype_distance)

    print("\n Class Pneumonia =>","\tPrototype Index: ", pneumonia_prototype_index, "\tPrototype Distance: ", pneumonia_prototype_distance)

    # get the membership of each test vector for each class
    covid_membership = getDegreeOfMembership("covid", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    normal_membership = getDegreeOfMembership("normal", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    pneumonia_membership = getDegreeOfMembership("pneumonia", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)

    print("\n Class Covid =>","\tMembership: ", covid_membership)

    print("\n Class Normal =>","\tMembership: ", normal_membership)

    print("\n Class Pneumonia =>","\tMembership: ", pneumonia_membership)

    # assign class to each test vector
    assigned_class = assignClass(covid_membership, normal_membership, pneumonia_membership)

    print("\n Assigned Class =>", assigned_class)
# Out:
#  Class Covid => 	Prototype Index:  869 	Prototype Distance:  3618.2429437504607
#
#  Class Normal => 	Prototype Index:  2560 	Prototype Distance:  3154.2480878967017
#
#  Class Pneumonia => 	Prototype Index:  23 	Prototype Distance:  3902.411444222663
#
#  Class Covid => 	Membership:  0.6610514286262241
#
#  Class Normal => 	Membership:  0.7045173859876708
#
#  Class Pneumonia => 	Membership:  0.6344311853861052
#
#  Assigned Class => normal

# %% [markdown]
# 3. Image without lungs

# %%
test_image  = cv2.imread('./wrong_test.png')
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# plot the test image 
plt.imshow(test_image, cmap='gray')
plt.title('Normal Test Image')
plt.show()

if not is_lung_image(test_image):
    print("The image does not contain lungs")
else:
    test_vector = get_img_vector(test_image)

    # get the distances of each test vector with each prototype of each class
    covid_prototype_index, covid_prototype_distance = getPrototype(test_vector, covid_prototypes)
    normal_prototype_index, normal_prototype_distance = getPrototype(test_vector, normal_prototypes)
    pneumonia_prototype_index, pneumonia_prototype_distance = getPrototype(test_vector, pneumonia_prototypes)

    print("\n Class Covid =>","\tPrototype Index: ", covid_prototype_index, "\tPrototype Distance: ", covid_prototype_distance)

    print("\n Class Normal =>","\tPrototype Index: ", normal_prototype_index, "\tPrototype Distance: ", normal_prototype_distance)

    print("\n Class Pneumonia =>","\tPrototype Index: ", pneumonia_prototype_index, "\tPrototype Distance: ", pneumonia_prototype_distance)

    # get the membership of each test vector for each class
    covid_membership = getDegreeOfMembership("covid", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    normal_membership = getDegreeOfMembership("normal", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)
    pneumonia_membership = getDegreeOfMembership("pneumonia", covid_prototype_distance, normal_prototype_distance, pneumonia_prototype_distance)

    print("\n Class Covid =>","\tMembership: ", covid_membership)

    print("\n Class Normal =>","\tMembership: ", normal_membership)

    print("\n Class Pneumonia =>","\tMembership: ", pneumonia_membership)

    # assign class to each test vector
    assigned_class = assignClass(covid_membership, normal_membership, pneumonia_membership)

    print("\n Assigned Class =>", assigned_class)
# Out:
# The image does not contain lungs
